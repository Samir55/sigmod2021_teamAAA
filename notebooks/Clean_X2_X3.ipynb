# %%
import pandas as pd
import os
import csv
import re
import logging
import optparse
import re
import spacy
import dedupe
import pickle
import copy
import json
from unidecode import unidecode

# %%
def formatNumber(num):
    num = float(num)
    if num % 1 == 0:
        return int(num)
    else:
        return num


def fill_nulls_with_none(df):
    """ Fills nulls in a dataframe with None.
        This is required for the Dedupe package to work properly.

        Input: - dataframe with nulls as NaN

        Output: - new dataframe with nulls as None
    """
    new_df = df.copy()
    for col in df.columns:
        new_df[col] = new_df[col].where(new_df[col].notnull(), None)
    return new_df


def convert_numbers_to_strings(df, cols_to_convert, remove_point_zero=True):
    """ Convert number types to strings in a dataframe.
        This is convoluted as need to keep NoneTypes as NoneTypes for what comes next!

        Inputs: - df -> dataframe to convert number types
                - cols_to_convert -> list of columns to convert
                - remove_point_zero -> bool to say whether you want '.0' removed from number

        Ouputs: - dataframe with converted number types
    """
    new_df = df.copy()
    for col in cols_to_convert:
        if remove_point_zero:
            new_df[col] = new_df[col].apply(lambda x: str(x).replace('.0', '') \
                if not isinstance(x, type(None)) else x)
        else:
            new_df[col] = new_df[col].apply(lambda x: str(x) \
                if not isinstance(x, type(None)) else x)
    return new_df

# %%
def clean_laptops_dataset(x_org):
    # Copy the dataset
    df = x_org.copy(deep=True)

    # Set the index
    df.set_index('instance_id', inplace=True, drop=False)

    spacy.cli.download("en_core_web_sm")
    sp = spacy.load('en_core_web_sm')

    # Read helper datasets stats
    extra_brands = set(
        pd.read_csv('../data/sigmod/laptops.csv', encoding='windows-1251').Company.str.lower().unique())
    screen_sizes = set(pd.read_csv('../data/sigmod/laptops.csv', encoding='windows-1251').Inches)
    screen_sizes = [str(formatNumber(str(s).lower())) for s in screen_sizes]

    # Keep only Alpha numeric
    irrelevant_regex = re.compile(r'[^a-z0-9,.\-\s]')
    multispace_regex = re.compile(r'\s\s+')  # Why it doesn't work
    multispace_regex_2 = re.compile(r'\s-\s')  # Why it doesn't work
    df.replace({r'[^\x00-\x7F]+': ''}, regex=True, inplace=True)

    for column in df.columns:
        if column == 'instance_id':
            continue
        df[column] = df[column].str.lower().str.replace(irrelevant_regex, ' ').str.replace(multispace_regex, ' ')

    # Tokenize the new title
    def tokenize_new_tile(record):
        return [w.text for w in sp(record['new_title'])]

    remove_words = ['with', 'clarinet', 'audiophile', 'end', 'pc', 'french', 'performance', '"', 'burner', 'sd',
                    'canada', 'certified',
                    'keyboard', 'backlight', 'professional', 'at', 'beats', 'drive', 'microphone', 'vology',
                    'america',
                    'refurbished', 'computer', 'dimm', 'ultrabase', 'audio', ':', 'switching', 'premium', 'special',
                    'dvd', 'portable',
                    'speaker', 'buy.net', 'downgrade', '/', '&', 'wireless', 'home', 'notebook', ')', 'edition',
                    'built-in',
                    'dualcore', 'high', 'revolve', 'cool', 'and', 'micro', 'aluminum', 'g', 'tigerdirect', 'voice',
                    'nx.m8eaa.007',
                    'comfyview', 'amazon.com', 'bes', 'ultraportable', 'gb', 'core', 'computers', 'screen', 'slot',
                    'lan', 'supermulti', 'technology', 'bluray', 'price', 'display', 'dvdrw', '.com',
                    'internationalaccessories',
                    'touch', 'card', 'us', 'bluetooth', 'dvdwriter', 'for', 'new', 'comparison', 'webcam', '(',
                    'laptop',
                    'accessories', 'brand', 'builtin']
    replace_words = {'hewlett-packard': 'hp'}

    def clean_title(record):
        title = record['title']

        # Remove unneeded words
        for w in remove_words:
            title = title.replace(w, '')

        # Replace words with common word
        for w, fix_w in replace_words.items():
            title = title.replace(w, fix_w)

        return title

    df['new_title'] = df.apply(clean_title, axis=1)
    irrelevant_regex = re.compile(r'[^a-z0-9.\s]')
    multispace_regex = re.compile(r'\s\s+')
    df['new_title'] = df.new_title.str.lower().str.replace(irrelevant_regex, '').str.replace(multispace_regex,
                                                                                             ' ').str.replace(
        multispace_regex_2, ' ')
    df['new_title_tokens'] = df.apply(tokenize_new_tile, axis=1)

    # Brand assignment
    all_brands = set(extra_brands)

    def assign_brand(record):
        # Search in brand first
        if record['brand'] in all_brands:
            return record['brand']
        # then in the title
        for el in all_brands:
            if el in record['title']:
                return el
        return None

    df['brand'] = df.apply(assign_brand, axis=1)

    # cpu brand
    intel = ['intel', 'i3', 'i5', 'i7', 'celeron', 'pentium']  # Needed because not all entries have intel

    def assign_cpu_brand(record):
        # Search in brand first
        for blue in intel:
            if blue in str(record['cpu_brand']) or blue in str(record['title']) or \
                    blue in str(record['cpu_model']) or blue in str(record['cpu_type']):
                return 'intel'
        return 'amd'

    df['cpu_brand'] = df.apply(assign_cpu_brand, axis=1)

    def assign_screen_size(record):
        brand_tokens = record['new_title_tokens']
        arr = []
        for t in brand_tokens:
            s = t.replace('inch', '')
            s = s.replace('in', '')
            arr.append(s)

        for sc in screen_sizes:
            if str(sc) in arr:
                return str(sc)

        else:
            return None

    df['screen_size'] = df.apply(assign_screen_size, axis=1)

    # ram capacity
    def assign_ram_capacity(record):
        s = str(record['ram_capacity'])
        t = str(record['title'])
        regex = re.compile(r'(\d{1,3})\s?([gm]b)')  # rare chance of encountering MB as an error
        m = None
        # ram_c = df['ram_capacity'].str.extract(regex)
        # title_ram = df['title'].str.extract(regex)
        if s:
            m = re.search(regex, s)
        if m is None:
            m = re.search(regex, t)
        if m is None:
            return None
        else:
            m = m.group()
            return re.sub(r'([gm]b)', "gb", m)

    def assign_hdd_capacity(record):
        s = str(record['hdd_capacity']).replace(' ', '')
        s2 = str(record['title'].replace(' ', ''))

        if 'ssd' in s:
            return 0

        if re.search("\d{3,4}gb", s):
            return str(re.findall("\d{3,4}gb", s)[0][:-2]) + ' gb'
        if re.search("\dtb", s):
            return str(re.findall("\dtb", s)[0][:-2] + '000') + ' gb'
        if re.search("\d{3,4}gbhdd", s2):
            return str(re.findall("\d{3,4}gbhdd", s2)[0][:-5]) + ' gb'
        if re.search("hdd\d{3,4}gb", s2):
            return str(re.findall("hdd\d{3,4}gb", s2)[0][3:-2]) + ' gb'
        if re.search("hdd\d{1}tb", s2):
            return str(re.findall("hdd\d{1}tb", s2)[0][3:4] + '000') + ' gb'
        if re.search("\d{1}tbhdd", s2):
            return str(re.findall("\d{1}tbhdd", s2)[0][0] + '000') + ' gb'
        return None

    df['hdd_capacity'] = df.apply(assign_hdd_capacity, axis=1)

    def assign_ssd_capacity(record):
        s = str(record['ssd_capacity']).replace(' ', '')
        s2 = str(record['title'].replace(' ', ''))

        if re.search("\d{3,4}gbssd", s):
            return str(re.findall("\d{3,4}gb", s)[0][:-2]) + ' gb'
        if re.search("\dtbssd", s):
            return str(re.findall("\dtb", s)[0][:-2] + '000') + ' gb'
        if re.search("\d{3,4}gbssd", s2):
            return str(re.findall("\d{3,4}gbssd", s2)[0][:-5]) + ' gb'
        if re.search("ssd\d{3,4}gb", s2):
            return str(re.findall("ssd\d{3,4}gb", s2)[0][3:-2]) + ' gb'
        if re.search("ssd\d{1}tb", s2):
            return str(re.findall("ssd\d{1}tb", s2)[0][3:4] + '000') + ' gb'
        if re.search("\d{1}tbssd", s2):
            return str(re.findall("\d{1}tbssd", s2)[0][0] + '000') + ' gb'
        return None

        # if re.search("\d{3,4}gbssd", s):
        #     return str(re.findall("\d{3,4}gb", s)[0][:-2]) + ' gb'
        # if re.search("\dtbssd", s):
        #     return str(re.findall("\dtb", s)[0][:-2] + '000') + ' gb'
        # if re.search("\d{3,4}gbssd", s2):
        #     return str(re.findall("\d{3,4}gbssd", s2)[0][:-5]) + ' gb'
        # if re.search("ssd\d{3,4}gb", s2):
        #     return str(re.findall("ssd\d{3,4}gb", s2)[0][3:-2]) + ' gb'
        # if re.search("ssd\d{1}tb", s2):
        #     return str(re.findall("ssd\d{1}tb", s2)[0][3:4] + '000') + ' gb'
        # if re.search("\d{1}tbssd", s2):
        #     return str(re.findall("\d{1}tbssd", s2)[0][0] + '000') + ' gb'
        # return None

    df['ssd_capacity'] = df.apply(assign_ssd_capacity, axis=1)

    def assign_laptop_model(record):
        brand = record['brand']
        t = record['new_title']

        if brand == 'acer':
            acer_regex = [r'\sv.-.....-', r'\se.-.....-?....?']
            for r in acer_regex:
                cr = re.compile(r)
                if re.search(cr, t):
                    return re.search(cr, t).group()

        if brand == 'asus':
            regex = [r'\sux...-.....']
            for r in regex:
                cr = re.compile(r)
                if re.search(cr, t):
                    return re.search(cr, t).group()

        if brand == 'lenovo':
            regex = [r'\sx\d{3}\s?tablet?\s?\d{0,4}', r'\sx\d{3}\s?laptop?\s?\d{0,4}', r'\sx\d{3}\s?\d{0,4}',
                     r'\sx\d{1}\scarbon\s\d{4}', r'\sx\d{1}\scarbon touch\s\d{4}']

            for r in regex:
                cr = re.compile(r)
                if re.search(cr, t):
                    res = re.search(cr, t).group()
                    for w in ['carbon', 'touch', 'tablet', 'laptop']:
                        res = res.replace(w, '')
                    return res

        if brand == 'hp':
            regex = [r'\sfolio\s?\d{4}.', r'\selitebook\s?\d{3,4}.']
            for r in regex:
                cr = re.compile(r)
                if re.search(cr, t):
                    res = re.search(cr, t).group()
                    for w in ['folio', 'elitebook']:
                        res = res.replace(w, '')
                    return res

        if brand == 'dell':
            regex = [r'\s[nmi]\d{3,4}(-\d{4})?']
            for r in regex:
                cr = re.compile(r)
                if re.search(cr, t):
                    res = re.search(cr, t).group()
                    for w in ['folio', 'elitebook']:
                        res = res.replace(w, '')
                    return res

        return None

    df['model'] = df.apply(assign_laptop_model, axis=1)
    df['ram_capacity'] = df.apply(assign_ram_capacity, axis=1)

    df = fill_nulls_with_none(df)
    df = convert_numbers_to_strings(df, ['screen_size'])

    def assign_model_name(record):  # laptop Line
        # print(record['model'].split())
        if record['model'] is None:
            return None;
        ans = record['model'].split(" ")[0]
        if ans.isalpha():
            return ans
        return None

    df['model_name'] = df.apply(assign_model_name, axis=1)

    def assign_cpu_model(record):
        model = record['cpu_model']
        if record['cpu_type'] is not None:
            if model is not None:
                model += ' '
                model += record['cpu_type']
            else:
                model = record['cpu_type']

        regex = re.compile(r"-?\d{3,4}([mul]{1,2})")  # For intel cpus
        regex2 = re.compile(r"[ea]\d?-\d{1,4}[m]?")  # for amd A and E series. Needs detection after AMD tag in title
        m = None
        if record['cpu_brand'] == 'intel' and model is not None:
            m = re.search(regex, model)
            if m is not None:
                m = m.group()
                return re.sub(r'-', "", m)
        if re.search("intel", record['title']):  # one case where laptop model is 50m and gets caught
            m = re.search(regex, record['title'])
            if m is not None:
                m = m.group()
                return re.sub(r'-', "", m)
        if record['cpu_brand'] == 'amd' and model is not None:
            m = re.search(regex2, model)
            if m is not None:
                m = m.group()
                return re.sub(r'[ea]\d?-', "", m)
        if re.search("amd", record['title']):
            m = re.search(regex2, record['title'])
            if m is not None:
                m = m.group()
                return re.sub(r'[ea]\d?-', "", m)
        if m is None:
            return None

    df['cpu_model'] = df.apply(assign_cpu_model, axis=1)

    def assign_cpu_type(record):
        # Find the cpu type
        cpu_list = ["i5", "i3", "i7", "atom",
                    "pentium", "celeron", "a-series",
                    "e-series", "aseries", "eseries",
                    "a1", "a2", "a3", "a4", "a5", "a6", "a7", "a8", "a9"]

        for cpu in cpu_list:
            if record['cpu_type'] is not None and cpu in str(record['cpu_type']):
                return cpu

            if record['cpu_model'] is not None and cpu in str(record['cpu_model']):
                return cpu
            if record['cpu_frequency'] is not None and cpu in str(record['cpu_frequency']):
                return cpu

            if cpu in str(record['title']):
                return cpu

            if re.search("e-[0-9]{3}", record['title']):
                return re.findall("e-[0-9]{3}", record['title'])[0]

            if record['cpu_model'] is not None and re.search("e-[0-9]{3}", record['cpu_model']):
                return re.findall("e-[0-9]{3}", record['cpu_model'])[0]

        return None

    df['cpu_type'] = df.apply(assign_cpu_type, axis=1)

    def assign_cpu_frequency(record):
        s = record['cpu_frequency']
        regex = re.compile(r"\d?.\d{1,2}\s?ghz")
        m = None
        if s:
            m = re.search(regex, s)
            if m is not None:
                m = m.group()
                return re.sub(r'ghz', "", m)
        if re.search("ghz", record['title']):
            m = re.search(regex, record['title'])
            if m is not None:
                m = m.group()
                return re.sub(r'ghz', "", m)
        if m is None:
            return None

    df['cpu_frequency'] = df.apply(assign_cpu_frequency, axis=1)

    def assign_new_title(record):
        # Remove extracted data from the title

        # Remove model name
        record['new_title'] = record['nwe_titl']

        # Remove brand
        # Remove screen size
        # Remove cpu brand
        # Remove cpu type
        # Ram capacity, hdd capacity, ssd capacity

    def assign_cpu(record):
        cpu_type = record['cpu_type']
        cpu_model = record['cpu_model']

        res = ""
        if cpu_type is not None:
            res += cpu_type

        if cpu_model is not None:
            res += '-'
            res += cpu_model

        return res

    df['cpu_model'] = df.apply(assign_cpu, axis=1)

    return df

# %%
# Read the X2 dataset and see what else can we get from just 
x2_org = pd.read_csv('../data/sigmod/X2.csv')

# Current cleaning output
x2_dev = clean_laptops_dataset(x2_org)
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
x2_dev.head()
# Out:
#                                        instance_id   brand cpu_brand  \
# instance_id
# www.softwarecity.ca//737  www.softwarecity.ca//737  lenovo     intel
# www.isupplyhub.com//1256  www.isupplyhub.com//1256    acer     intel
# www.isupplyhub.com//326    www.isupplyhub.com//326    acer     intel
# www.isupplyhub.com//821    www.isupplyhub.com//821      hp       amd
# www.isupplyhub.com//157    www.isupplyhub.com//157    asus     intel
#
#                          cpu_model cpu_type cpu_frequency ram_capacity  \
# instance_id
# www.softwarecity.ca//737  i5-3320m       i5         2.60          4 gb
# www.isupplyhub.com//1256  i5-4200u       i5          1.6          8 gb
# www.isupplyhub.com//326   i5-4200u       i5          1.6          4 gb
# www.isupplyhub.com//821      -2100     None          None         4 gb
# www.isupplyhub.com//157   i5-3317u       i5          1.7          4 gb
#
#                                                              ram_type  \
# instance_id
# www.softwarecity.ca//737  ddr3 sdram. ddr3-1600 pc3-12800. ddr3 sdram
# www.isupplyhub.com//1256                 ddr3 sdram. 8 gb ddr3l sdram
# www.isupplyhub.com//326                   ddr3 sdram. 4 gb ddr3-sdram
# www.isupplyhub.com//821                   ddr3 sdram. 4 gb sdram ddr3
# www.isupplyhub.com//157                         ddr3 sdram. 4 gb ddr3
#
#                                 ram_frequency hdd_capacity ssd_capacity  \
# instance_id
# www.softwarecity.ca//737  ddr3-1600 pc3-12800       320 gb         None
# www.isupplyhub.com//1256                 None       500 gb         None
# www.isupplyhub.com//326                  None       500 gb         None
# www.isupplyhub.com//821                  None       500 gb         None
# www.isupplyhub.com//157                  None         None       256 gb
#
#                               weight                   dimensions  \
# instance_id
# www.softwarecity.ca//737     1.80 kg                         None
# www.isupplyhub.com//1256  4.8 pounds  15.02 x 10.08 x 0.90 inches
# www.isupplyhub.com//326   5.2 pounds     15.02 x 10.08 x 1 inches
# www.isupplyhub.com//821   4.8 pounds  15.18 x 0.89 x 10.16 inches
# www.isupplyhub.com//157   2.9 pounds   8.80 x 0.70 x 12.80 inches
#
#                                                                       title  \
# instance_id
# www.softwarecity.ca//737  lenovo thinkpad x230 34352jf tablet pc - 12.5 ...
# www.isupplyhub.com//1256  amazon.com acer aspire v7-582pg-6479 15.6-inch...
# www.isupplyhub.com//326   amazon.com acer aspire e1-572-6870 15.6 inch l...
# www.isupplyhub.com//821   amazon.com 15.6 hp 15-f009wm amd dual-core e1-...
# www.isupplyhub.com//157   amazon.com asus ux31a-xb52 13.3-inch ultrabook...
#
#                                                                   new_title  \
# instance_id
# www.softwarecity.ca//737  lenovo thinkpad x230 34352jf tablet 12.5 inpe ...
# www.isupplyhub.com//1256   acer aspire v7582p6479 15.6inch ultrabook ste...
# www.isupplyhub.com//326    acer aspire e15726870 15.6 inch intel i5 4200...
# www.isupplyhub.com//821    15.6 hp 15f009wm amd dual e12100 4b ddr3 ram ...
# www.isupplyhub.com//157    as ux31axb52 13.3inch ultrabook 1.7 hz intel ...
#
#                                                            new_title_tokens  \
# instance_id
# www.softwarecity.ca//737  [lenovo, thinkpad, x230, 34352jf, tablet, 12.5...
# www.isupplyhub.com//1256  [ , acer, aspire, v7582p6479, 15.6inch, ultrab...
# www.isupplyhub.com//326   [ , acer, aspire, e15726870, 15.6, inch, intel...
# www.isupplyhub.com//821   [ , 15.6, hp, 15f009wm, amd, dual, e12100, 4b,...
# www.isupplyhub.com//157   [ , as, ux31axb52, 13.3inch, ultrabook, 1.7, h...
#
#                          screen_size       model model_name
# instance_id
# www.softwarecity.ca//737        12.5   x230 3435       None
# www.isupplyhub.com//1256        15.6        None       None
# www.isupplyhub.com//326         15.6        None       None
# www.isupplyhub.com//821         15.6        None       None
# www.isupplyhub.com//157         13.3        None       None

# %%
# Extract the cpu model

# Improve the laptop model

# Use CPU frequency

# During Inference: Parition by screen size / brand and then do the blocking (During the inference)

# Use Py-entity matching and try it

# Remove any extracted words

# %%
# Remove any unncessary words
# all_tokens = []
# for i in range(len(x2_dev)):
#     record = x2_dev.iloc[i]
#     all_tokens.extend(list(record.new_title_tokens))

# %%
from collections import Counter

# Counter((all_tokens))

# %%
# Get all alpha only words
all_alpa_words = [i for i in (all_tokens) if i.isalpha()]
# set(all_alpa_words)

# %%
words_to_remove = [
    'aluminum',
    'america',
    'and',
    'at',
    'audio',
    'audiophile',
    'backlight',
    'beats',
    'bluetooth',
    'bluray',
    'brand',
    'builtin',
    'burner',
    'buy.net',
    'canada',
    'card',
    'certified',
    'clarinet',
    'comfyview',
    'comparison',
    'computer',
    'computers',
    'cool',
    'dimm',
    'display',
    'downgrade',
    'drive',
    'dvd',
    'dvdrw',
    'dvdwriter',
    'edition',
    'end',
    'for',
    'french',
    'g',
    'gb',
    'high',
    'home',
    'internationalaccessories',
    'keyboard',
    'lan',
    'portable',
    'premium',
    'price',
    'professional',
    'refurbished',
    'revolve',
    'screen',
    'slot',
    'special',
    'supermulti',
    'switching',
    'technology',
    'touch',
    'ultrabase',
    'us',
    'voice',
    'vology',
    'webcam',
    'dualcore'
]

words_to_replace = {'hewlettpackard': 'hp'}

# %%
# Brands laptop model regex

# %%
{'acer',
 'apple',
 'asus',
 'chuwi',
 'dell',
 'fujitsu',
 'google',
 'hp',
 'huawei',
 'lenovo',
 'lg',
 'mediacom',
 'microsoft',
 'msi',
 'razer',
 'samsung',
 'toshiba',
 'vero',
 'xiaomi'}
# Out:
# {'acer',
#  'apple',
#  'asus',
#  'chuwi',
#  'dell',
#  'fujitsu',
#  'google',
#  'hp',
#  'huawei',
#  'lenovo',
#  'lg',
#  'mediacom',
#  'microsoft',
#  'msi',
#  'razer',
#  'samsung',
#  'toshiba',
#  'vero',
#  'xiaomi'}

# %%
grouped = x2_dev.groupby(['brand'])
output = []
for g in grouped.groups.keys():
    output.append(x2_dev.loc[grouped.groups[g]])
print("Number of groups", len(output))
# Out:
# Number of groups 5

# %%
acer_title = list(output[0].title)
acer_title
# Out:
# ['amazon.com acer aspire v7-582pg-6479 15.6-inch touchscreen ultrabook cool steel computers accessories',
#  'amazon.com acer aspire e1-572-6870 15.6 inch laptop intel i5 4200u 1.6ghz processor, 4gb ram, 500gb hard drive, windows 8 clarinet black laptop computers computers accessories',
#  'amazon.com acer aspire nx.mg7aa.005 e1-771-6496 17.3-inch laptop computers accessories',
#  'amazon.com acer aspire v3-772g-9460 17.3 led notebook intel core i7-4702mq 2.20 ghz 12gb ddr3 1tb hdd 120gb ssd blu-ray reader dvd-writer nvidia geforce gtx 760m windows 8 black laptop computers computers accessories',
#  'amazon.com acer aspire v3-572pg-767j 15.6-inch touchscreen laptop platinum silver computers accessories',
#  'amazon.com acer aspire v3-572-78s3 15.6-inch laptop platinum silver computers accessories',
#  'amazon.com acer aspire e3-111-c5gl 11.6-inch laptop cool silver computers accessories',
#  'amazon.com acer aspire v3-111p-43bc 11.6-inch touchscreen laptop cool silver computers accessories',
#  'amazon.com acer aspire v7-482pg-5842 14-inch touchscreen ultrabook cool steel computers accessories',
#  'amazon.com acer aspire nx.mg7aa.006 e1-771-6458 17.3-inch laptop computers accessories',
#  'acer aspire e1-771-33116g50mnii - 17.3 - core i3 3110m - windows 7 home premium 64-bit - 6 gb ram - 500 gb hdd',
#  'acer aspire e5-771-37gd 17.3 notebook computer, intel core i3-4030u 1.8ghz processor, 4gb ram, 500gb hdd, windows 8.1, iron silver',
#  'acer aspire e1-572-34014g50mnkk - 15.6 - core i3 4010u - windows 7 home premium 64-bit - 4 gb ram - 500 gb hdd',
#  'acer aspire e1-572-54204g50mnrr - 15.6 - core i5 4200u - windows 7 home premium 64-bit - 4 gb ram - 500 gb hdd',
#  'acer aspire e1-771-53236g50mnii - 17.3 - core i5 3230m - windows 7 home premium 64-bit - 6 gb ram - 500 gb hdd',
#  'acer aspire e1-572-54204g50mnkk - 15.6 - core i5 4200u - windows 7 home premium 64-bit - 4 gb ram - 500 gb hdd',
#  'acer aspire e1-572-34014g50mnrr - 15.6 - core i3 4010u - windows 7 home premium 64-bit - 4 gb ram - 500 gb hdd',
#  'acer aspire e1-731-20204g50mnii - 17.3 - pentium 2020m - windows 7 home premium 64-bit - 4 gb ram - 500 gb hdd',
#  'acer aspire v3-111p-43bc 11.6 touchscreen notebook computer, intel pentium n3530 quad-core 2.16ghz, 4gb ram, 500gb hdd, windows 8.1, cool silver',
#  'acer aspire v3-572-78s3 15.6 notebook computer, intel core i7-4510u 2ghz, 8gb ram, 1tb hdd, windows 8.1, platinum silver',
#  'acer aspire e1-532-29574g50mnrr - 15.6 - celeron 2957u - windows 7 home premium 64-bit - 4 gb ram - 500 gb hdd',
#  'acer aspire v3-572pg-767j 15.6 touchscreen notebook computer, intel core i7-4510u 2ghz, 8gb ram, 1tb hdd, windows 8.1, platinum silver',
#  'acer aspire e1-532-29574g50mnkk - 15.6 - celeron 2957u - windows 7 home premium 64-bit - 4 gb ram - 500 gb hdd',
#  'acer aspire e1-522-5423 - 15.6 - a series a4-5000 - windows 8.1 64-bit - 4 gb ram - 500 gb hdd',
#  'amazon.com lb1 high performance new acer black silver aspire e e1-571-6607 15.6 laptop pc with intel core i3-2348m processor 4gb memory 500gb hard drive and windows 7 home premium 64-bit high end professional audiophile wireless bluetooth mini speaker portable with built-in microphone and micro sd card slot silver computers accessories',
#  'amazon.com lb1 high performance new acer black silver aspire e e1-571-6607 15.6 laptop pc with intel core i3-2348m processor 4gb memory 500gb hard drive and windows 7 home premium 64-bit high end professional audiophile wireless bluetooth mini speaker portable with built-in microphone and micro sd card slot silver computers accessories',
#  'amazon.com brand new acer america corp. acer aspire e1-572-34014g50mnkk 15.6 led notebook - intel core i3 i3-4010u 1.70 ghz - black computers accessories',
#  'amazon.com acer aspire e5-771-37gd 17.3 notebook computer, intel core i3-4030u 1.8ghz processor, 4gb ram, 500gb hdd, windows 8.1, iron silver computers accessories',
#  'amazon.com lb1 high performance new acer black silver aspire e e1-571-6607 15.6 laptop pc with intel core i3-2348m processor 4gb memory 500gb hard drive and windows 7 home premium 64-bit high end professional audiophile wireless bluetooth mini speaker with built-in microphone - micro sd card slot - voice prompt silver computers accessories',
#  'amazon.com acer nx.m8eaa.007 aspire e1-572-34014g50mnkk 15.6 led notebook - intel core i3 i3-4010u 1.70 ghz - black 4 gb ram - 500 gb hdd - dvd-writer - intel hd 4400 graphics - windows 7 home premium 64-bit - 1366 x 768 display - bluetooth computers accessories',
#  'amazon.com acer aspire e1-572-34014g50mnkk 15.6 led notebook - intel core i3 i3-4010u 1.70 ghz - black 4 gb ram - 500 gb hdd - dvd-writer - intel hd 4400 graphics - windows 7 home premium 64-bit - 1366 x 768 display - bluetooth nx.m8eaa.007 computers accessories',
#  'amazon.com acer aspire nx.mpsaa.002 e5-571-30f1 15.6-inch laptop computers accessories',
#  'amazon.com acer aspire e1-571-32344g50mnks 15.6 led notebook - intel core i3 i3-2348m 2.30 ghz laptop computers computers accessories',
#  'amazon.com acer aspire e3-111-c5gl 11.6-inch laptop cool silver computers accessories',
#  'amazon.com acer aspire nx.mg7aa.006 e1-771-6458 17.3-inch laptop computers accessories',
#  'amazon.com acer aspire e1-572-6870 15.6 inch laptop intel i5 4200u 1.6ghz processor, 4gb ram, 500gb hard drive, windows 8 clarinet black laptop computers computers accessories',
#  'amazon.com acer aspire nx.mhfaa.002 e1-572-6484 15.6-inch laptop computers accessories',
#  'amazon.com acer aspire v7-482pg-5842 14-inch touchscreen ultrabook cool steel computers accessories',
#  'amazon.com acer aspire e1-572-34014g50mnrr 15.6 led notebook intel core i3-4010u 1.70 ghz 4gb ddr3 500gb hdd dvd-writer intel hd graphics 4400 windows 7 home premium 64-bit red computers accessories',
#  'amazon.com acer acer aspire e1-771-33116g50mnii - core i3 3110m 2.4 ghz - windows 7 home premium 64-bit - 6 gb ram - 500 gb hdd - dvd supermulti - 17.3 cinecrystal wide 1600 x 900 hd - intel hd graphics 4000 - iron imr - keyboard us international nx.mg7aa.006 computers accessories',
#  'amazon.com lb1 high performance new wireless bluetooth mini speaker for acer black silver aspire e e1-571-6607 15.6 laptop pc with intel core i3-2348m processor 4gb memory 500gb hard drive and windows 7 home premium 64-bit with built-in microphone - micro sd card slot - voice prompt silver computers accessories',
#  'amazon.com acer aspire e1-571-6607, 16 - inch notebook windows 7 home premium 64-bit, intel core i3 2348m 2.30ghz 4gb memory 500gb hdd laptop computers computers accessories',
#  'amazon.com acer aspire nx.mltaa.011 e5-571-38kj 15.6-inch laptop computers accessories',
#  'amazon.com acer aspire e1-771-6603 17.3-inch laptop 2.4 ghz intel core i3-3110m processor, 6gb ddr3, 750gb hdd, windows 8 steel gray laptop computers computers accessories',
#  'amazon.com acer aspire v3-111p-43bc 11.6-inch touchscreen laptop cool silver computers accessories',
#  'amazon.com acer aspire e1-572p-6468 16-inch touchscreen notebook 1.7ghz intel core i3-4010u, 4gb ram, 500gb hdd, windows 8.1 notebook computers computers accessories',
#  'amazon.com acer aspire e3-111-c5gl 11.6-inch laptop cool silver computers accessories',
#  'amazon.com lb1 high performance new wireless bluetooth mini speaker portable for acer black silver aspire e e1-571-6607 15.6 laptop pc with intel core i3-2348m processor 4gb memory 500gb hard drive and windows 7 home premium 64-bit with built-in microphone and micro sd card slot silver computers accessories',
#  'amazon.com brand new acer america corp. acer aspire e1-572-34014g50mnrr 15.6 led notebook - intel core i3 i3-4010u 1.70 ghz - red computers accessories',
#  'acer aspire v3-772g-747a121.12tbdcckk 17.3 led comfyview notebook - intel core i7 i7-4702mq 2.20 ghz - black 12 gb ram - 1 tb hdd - 120 gb ssd - blu-ray reader dvd-writer - nvidia geforce gtx 760m - windows 8 64-bit - 1920 x 1080 display - bluetooth price comparison at buy.net',
#  'acer aspire e1-572-54204g50mnrr 15.6 led notebook - intel core i5 i5-4200u 1.60 ghz - red 4 gb ram - 500 gb hdd - dvd-writer - intel hd 4400 - windows 7 home premium 64-bit - 1366 x 768 display - bluetooth price comparison at buy.net',
#  'acer aspire v5-573p-54208g1taii 15.6 touchscreen led notebook - intel core i5 i5-4200u 1.60 ghz 8 gb ram - 1 tb hdd - intel hd 4400 - windows 8.1 64-bit - 1366 x 768 display - bluetooth price comparison at buy.net',
#  'acer aspire e1-771-53236g50mnii 17.3 led notebook - intel core i5 i5-3230m 2.60 ghz 6 gb ram - 500 gb hdd - dvd-writer - intel hd 4000 - windows 7 home premium 64-bit - 1600 x 900 display - bluetooth price comparison at buy.net',
#  'acer aspire v5-573p-54208g1tarr 15.6 touchscreen led notebook - intel core i5 i5-4200u 1.60 ghz - red 8 gb ram - 1 tb hdd - intel hd 4400 - windows 8.1 64-bit - 1366 x 768 display - bluetooth price comparison at buy.net',
#  'acer aspire e1-532-29574g50mnrr 15.6 led notebook - intel celeron 2957u 1.40 ghz - red 4 gb ram - 500 gb hdd - dvd-writer - intel hd graphics - windows 7 home premium 64-bit - 1366 x 768 display - bluetooth price comparison at buy.net',
#  'acer aspire e1-572-34014g50mnrr 15.6 led notebook - intel core i3 i3-4010u 1.70 ghz - red 4 gb ram - 500 gb hdd - dvd-writer - intel hd 4400 - windows 7 home premium 64-bit - 1366 x 768 display - bluetooth price comparison at buy.net',
#  'acer aspire e1-532-29574g50mnkk 15.6 led notebook - intel celeron 2957u 1.40 ghz - black 4 gb ram - 500 gb hdd - dvd-writer - intel hd graphics - windows 7 home premium 64-bit - 1366 x 768 display - bluetooth price comparison at buy.net',
#  'acer aspire e1-731-20204g50mnii 17.3 led notebook - intel pentium 2020m 2.40 ghz 4 gb ram - 500 gb hdd - dvd-writer - intel hd graphics - windows 7 home premium 64-bit - 1600 x 900 display - bluetooth price comparison at buy.net',
#  'acer aspire e1-771-33116g50mnii 17.3 led notebook - intel core i3 i3-3110m 2.40 ghz 6 gb ram - 500 gb hdd - dvd-writer - intel hd 4000 - windows 7 home premium 64-bit - 1600 x 900 display - bluetooth price comparison at buy.net',
#  'acer aspire e1-522-45004g50mnkk 15.6 led notebook - amd a-series a4-5000 1.50 ghz - black 4 gb ram - 500 gb hdd - dvd-writer - amd radeon hd 8330 - windows 8.1 64-bit - 1366 x 768 display - bluetooth price comparison at buy.net',
#  'acer aspire e1-572-34014g50mnkk 15.6 led notebook - intel core i3 i3-4010u 1.70 ghz - black 4 gb ram - 500 gb hdd - dvd-writer - intel hd 4400 - windows 7 home premium 64-bit - 1366 x 768 display - bluetooth price comparison at buy.net']

# %%
acer_regex = [r'\sv.-.....-?....?', r'\se.-.....-?....?']
c = 0
for r in acer_regex:
    cr = re.compile(r)
    for t in acer_title:
        if re.search(cr, t):
            print(re.search(cr, t).group(), t)
            c+=1
print()
print(c)
# Out:
#  v7-582pg-6479 amazon.com acer aspire v7-582pg-6479 15.6-inch touchscreen ultrabook cool steel computers accessories
#  v3-772g-9460 amazon.com acer aspire v3-772g-9460 17.3 led notebook intel core i7-4702mq 2.20 ghz 12gb ddr3 1tb hdd 120gb ssd blu-ray reader dvd-writer nvidia geforce gtx 760m windows 8 black laptop computers computers accessories
#  v3-572pg-767j amazon.com acer aspire v3-572pg-767j 15.6-inch touchscreen laptop platinum silver computers accessories
#  v3-572-78s3  amazon.com acer aspire v3-572-78s3 15.6-inch laptop platinum silver computers accessories
#  v3-111p-43bc amazon.com acer aspire v3-111p-43bc 11.6-inch touchscreen laptop cool silver computers accessories
#  v7-482pg-5842 amazon.com acer aspire v7-482pg-5842 14-inch touchscreen ultrabook cool steel computers accessories
#  v3-111p-43bc acer aspire v3-111p-43bc 11.6 touchscreen notebook computer, intel pentium n3530 quad-core 2.16ghz, 4gb ram, 500gb hdd, windows 8.1, cool silver
#  v3-572-78s3  acer aspire v3-572-78s3 15.6 notebook computer, intel core i7-4510u 2ghz, 8gb ram, 1tb hdd, windows 8.1, platinum silver
#  v3-572pg-767j acer aspire v3-572pg-767j 15.6 touchscreen notebook computer, intel core i7-4510u 2ghz, 8gb ram, 1tb hdd, windows 8.1, platinum silver
#  v7-482pg-5842 amazon.com acer aspire v7-482pg-5842 14-inch touchscreen ultrabook cool steel computers accessories
#  v3-111p-43bc amazon.com acer aspire v3-111p-43bc 11.6-inch touchscreen laptop cool silver computers accessories
#  v3-772g-747a acer aspire v3-772g-747a121.12tbdcckk 17.3 led comfyview notebook - intel core i7 i7-4702mq 2.20 ghz - black 12 gb ram - 1 tb hdd - 120 gb ssd - blu-ray reader dvd-writer - nvidia geforce gtx 760m - windows 8 64-bit - 1920 x 1080 display - bluetooth price comparison at buy.net
#  v5-573p-5420 acer aspire v5-573p-54208g1taii 15.6 touchscreen led notebook - intel core i5 i5-4200u 1.60 ghz 8 gb ram - 1 tb hdd - intel hd 4400 - windows 8.1 64-bit - 1366 x 768 display - bluetooth price comparison at buy.net
#  v5-573p-5420 acer aspire v5-573p-54208g1tarr 15.6 touchscreen led notebook - intel core i5 i5-4200u 1.60 ghz - red 8 gb ram - 1 tb hdd - intel hd 4400 - windows 8.1 64-bit - 1366 x 768 display - bluetooth price comparison at buy.net
#  e1-572-6870  amazon.com acer aspire e1-572-6870 15.6 inch laptop intel i5 4200u 1.6ghz processor, 4gb ram, 500gb hard drive, windows 8 clarinet black laptop computers computers accessories
#  e1-771-6496  amazon.com acer aspire nx.mg7aa.005 e1-771-6496 17.3-inch laptop computers accessories
#  e3-111-c5gl  amazon.com acer aspire e3-111-c5gl 11.6-inch laptop cool silver computers accessories
#  e1-771-6458  amazon.com acer aspire nx.mg7aa.006 e1-771-6458 17.3-inch laptop computers accessories
#  e1-771-33116 acer aspire e1-771-33116g50mnii - 17.3 - core i3 3110m - windows 7 home premium 64-bit - 6 gb ram - 500 gb hdd
#  e5-771-37gd  acer aspire e5-771-37gd 17.3 notebook computer, intel core i3-4030u 1.8ghz processor, 4gb ram, 500gb hdd, windows 8.1, iron silver
#  e1-572-34014 acer aspire e1-572-34014g50mnkk - 15.6 - core i3 4010u - windows 7 home premium 64-bit - 4 gb ram - 500 gb hdd
#  e1-572-54204 acer aspire e1-572-54204g50mnrr - 15.6 - core i5 4200u - windows 7 home premium 64-bit - 4 gb ram - 500 gb hdd
#  e1-771-53236 acer aspire e1-771-53236g50mnii - 17.3 - core i5 3230m - windows 7 home premium 64-bit - 6 gb ram - 500 gb hdd
#  e1-572-54204 acer aspire e1-572-54204g50mnkk - 15.6 - core i5 4200u - windows 7 home premium 64-bit - 4 gb ram - 500 gb hdd
#  e1-572-34014 acer aspire e1-572-34014g50mnrr - 15.6 - core i3 4010u - windows 7 home premium 64-bit - 4 gb ram - 500 gb hdd
#  e1-731-20204 acer aspire e1-731-20204g50mnii - 17.3 - pentium 2020m - windows 7 home premium 64-bit - 4 gb ram - 500 gb hdd
#  e1-532-29574 acer aspire e1-532-29574g50mnrr - 15.6 - celeron 2957u - windows 7 home premium 64-bit - 4 gb ram - 500 gb hdd
#  e1-532-29574 acer aspire e1-532-29574g50mnkk - 15.6 - celeron 2957u - windows 7 home premium 64-bit - 4 gb ram - 500 gb hdd
#  e1-522-5423  acer aspire e1-522-5423 - 15.6 - a series a4-5000 - windows 8.1 64-bit - 4 gb ram - 500 gb hdd
#  e1-571-6607  amazon.com lb1 high performance new acer black silver aspire e e1-571-6607 15.6 laptop pc with intel core i3-2348m processor 4gb memory 500gb hard drive and windows 7 home premium 64-bit high end professional audiophile wireless bluetooth mini speaker portable with built-in microphone and micro sd card slot silver computers accessories
#  e1-571-6607  amazon.com lb1 high performance new acer black silver aspire e e1-571-6607 15.6 laptop pc with intel core i3-2348m processor 4gb memory 500gb hard drive and windows 7 home premium 64-bit high end professional audiophile wireless bluetooth mini speaker portable with built-in microphone and micro sd card slot silver computers accessories
#  e1-572-34014 amazon.com brand new acer america corp. acer aspire e1-572-34014g50mnkk 15.6 led notebook - intel core i3 i3-4010u 1.70 ghz - black computers accessories
#  e5-771-37gd  amazon.com acer aspire e5-771-37gd 17.3 notebook computer, intel core i3-4030u 1.8ghz processor, 4gb ram, 500gb hdd, windows 8.1, iron silver computers accessories
#  e1-571-6607  amazon.com lb1 high performance new acer black silver aspire e e1-571-6607 15.6 laptop pc with intel core i3-2348m processor 4gb memory 500gb hard drive and windows 7 home premium 64-bit high end professional audiophile wireless bluetooth mini speaker with built-in microphone - micro sd card slot - voice prompt silver computers accessories
#  e1-572-34014 amazon.com acer nx.m8eaa.007 aspire e1-572-34014g50mnkk 15.6 led notebook - intel core i3 i3-4010u 1.70 ghz - black 4 gb ram - 500 gb hdd - dvd-writer - intel hd 4400 graphics - windows 7 home premium 64-bit - 1366 x 768 display - bluetooth computers accessories
#  e1-572-34014 amazon.com acer aspire e1-572-34014g50mnkk 15.6 led notebook - intel core i3 i3-4010u 1.70 ghz - black 4 gb ram - 500 gb hdd - dvd-writer - intel hd 4400 graphics - windows 7 home premium 64-bit - 1366 x 768 display - bluetooth nx.m8eaa.007 computers accessories
#  e5-571-30f1  amazon.com acer aspire nx.mpsaa.002 e5-571-30f1 15.6-inch laptop computers accessories
#  e1-571-32344 amazon.com acer aspire e1-571-32344g50mnks 15.6 led notebook - intel core i3 i3-2348m 2.30 ghz laptop computers computers accessories
#  e3-111-c5gl  amazon.com acer aspire e3-111-c5gl 11.6-inch laptop cool silver computers accessories
#  e1-771-6458  amazon.com acer aspire nx.mg7aa.006 e1-771-6458 17.3-inch laptop computers accessories
#  e1-572-6870  amazon.com acer aspire e1-572-6870 15.6 inch laptop intel i5 4200u 1.6ghz processor, 4gb ram, 500gb hard drive, windows 8 clarinet black laptop computers computers accessories
#  e1-572-6484  amazon.com acer aspire nx.mhfaa.002 e1-572-6484 15.6-inch laptop computers accessories
#  e1-572-34014 amazon.com acer aspire e1-572-34014g50mnrr 15.6 led notebook intel core i3-4010u 1.70 ghz 4gb ddr3 500gb hdd dvd-writer intel hd graphics 4400 windows 7 home premium 64-bit red computers accessories
#  e1-771-33116 amazon.com acer acer aspire e1-771-33116g50mnii - core i3 3110m 2.4 ghz - windows 7 home premium 64-bit - 6 gb ram - 500 gb hdd - dvd supermulti - 17.3 cinecrystal wide 1600 x 900 hd - intel hd graphics 4000 - iron imr - keyboard us international nx.mg7aa.006 computers accessories
#  e1-571-6607  amazon.com lb1 high performance new wireless bluetooth mini speaker for acer black silver aspire e e1-571-6607 15.6 laptop pc with intel core i3-2348m processor 4gb memory 500gb hard drive and windows 7 home premium 64-bit with built-in microphone - micro sd card slot - voice prompt silver computers accessories
#  e1-571-6607, amazon.com acer aspire e1-571-6607, 16 - inch notebook windows 7 home premium 64-bit, intel core i3 2348m 2.30ghz 4gb memory 500gb hdd laptop computers computers accessories
#  e5-571-38kj  amazon.com acer aspire nx.mltaa.011 e5-571-38kj 15.6-inch laptop computers accessories
#  e1-771-6603  amazon.com acer aspire e1-771-6603 17.3-inch laptop 2.4 ghz intel core i3-3110m processor, 6gb ddr3, 750gb hdd, windows 8 steel gray laptop computers computers accessories
#  e1-572p-6468 amazon.com acer aspire e1-572p-6468 16-inch touchscreen notebook 1.7ghz intel core i3-4010u, 4gb ram, 500gb hdd, windows 8.1 notebook computers computers accessories
#  e3-111-c5gl  amazon.com acer aspire e3-111-c5gl 11.6-inch laptop cool silver computers accessories
#  e1-571-6607  amazon.com lb1 high performance new wireless bluetooth mini speaker portable for acer black silver aspire e e1-571-6607 15.6 laptop pc with intel core i3-2348m processor 4gb memory 500gb hard drive and windows 7 home premium 64-bit with built-in microphone and micro sd card slot silver computers accessories
#  e1-572-34014 amazon.com brand new acer america corp. acer aspire e1-572-34014g50mnrr 15.6 led notebook - intel core i3 i3-4010u 1.70 ghz - red computers accessories
#  e1-572-54204 acer aspire e1-572-54204g50mnrr 15.6 led notebook - intel core i5 i5-4200u 1.60 ghz - red 4 gb ram - 500 gb hdd - dvd-writer - intel hd 4400 - windows 7 home premium 64-bit - 1366 x 768 display - bluetooth price comparison at buy.net
#  e1-771-53236 acer aspire e1-771-53236g50mnii 17.3 led notebook - intel core i5 i5-3230m 2.60 ghz 6 gb ram - 500 gb hdd - dvd-writer - intel hd 4000 - windows 7 home premium 64-bit - 1600 x 900 display - bluetooth price comparison at buy.net
#  e1-532-29574 acer aspire e1-532-29574g50mnrr 15.6 led notebook - intel celeron 2957u 1.40 ghz - red 4 gb ram - 500 gb hdd - dvd-writer - intel hd graphics - windows 7 home premium 64-bit - 1366 x 768 display - bluetooth price comparison at buy.net
#  e1-572-34014 acer aspire e1-572-34014g50mnrr 15.6 led notebook - intel core i3 i3-4010u 1.70 ghz - red 4 gb ram - 500 gb hdd - dvd-writer - intel hd 4400 - windows 7 home premium 64-bit - 1366 x 768 display - bluetooth price comparison at buy.net
#  e1-532-29574 acer aspire e1-532-29574g50mnkk 15.6 led notebook - intel celeron 2957u 1.40 ghz - black 4 gb ram - 500 gb hdd - dvd-writer - intel hd graphics - windows 7 home premium 64-bit - 1366 x 768 display - bluetooth price comparison at buy.net
#  e1-731-20204 acer aspire e1-731-20204g50mnii 17.3 led notebook - intel pentium 2020m 2.40 ghz 4 gb ram - 500 gb hdd - dvd-writer - intel hd graphics - windows 7 home premium 64-bit - 1600 x 900 display - bluetooth price comparison at buy.net
#  e1-771-33116 acer aspire e1-771-33116g50mnii 17.3 led notebook - intel core i3 i3-3110m 2.40 ghz 6 gb ram - 500 gb hdd - dvd-writer - intel hd 4000 - windows 7 home premium 64-bit - 1600 x 900 display - bluetooth price comparison at buy.net
#  e1-522-45004 acer aspire e1-522-45004g50mnkk 15.6 led notebook - amd a-series a4-5000 1.50 ghz - black 4 gb ram - 500 gb hdd - dvd-writer - amd radeon hd 8330 - windows 8.1 64-bit - 1366 x 768 display - bluetooth price comparison at buy.net
#  e1-572-34014 acer aspire e1-572-34014g50mnkk 15.6 led notebook - intel core i3 i3-4010u 1.70 ghz - black 4 gb ram - 500 gb hdd - dvd-writer - intel hd 4400 - windows 7 home premium 64-bit - 1366 x 768 display - bluetooth price comparison at buy.net
#
# 61

# %%
c = 0
for r in acer_regex:
    cr = re.compile(r)
    for t in acer_title:
        if re.search(cr, t):
            print(re.search(cr, t).group(), t)
            c+=1
print()
print(c)
# Out:
#  v7-582pg-6479  acer aspire v7-582pg-6479 15.6-inch touchscreen ultrabook cool steel computers accessories
#  v3-772g-9460  acer aspire v3-772g-9460 17.3 led notebook intel core i7-4702mq 2.20 ghz 12gb ddr3 1tb hdd 120gb ssd blu-ray reader dvd-writer nvidia geforce gtx 760m windows 8 black laptop computers computers accessories
#  v3-572pg-767j  acer aspire v3-572pg-767j 15.6-inch touchscreen laptop platinum silver computers accessories
#  v3-572-78s3   acer aspire v3-572-78s3 15.6-inch laptop platinum silver computers accessories
#  v3-111p-43bc  acer aspire v3-111p-43bc 11.6-inch touchscreen laptop cool silver computers accessories
#  v7-482pg-5842  acer aspire v7-482pg-5842 14-inch touchscreen ultrabook cool steel computers accessories
#  v3-111p-43bc acer aspire v3-111p-43bc 11.6 touchscreen notebook computer, intel pentium n3530 quad-core 2.16ghz, 4gb ram, 500gb hdd, windows 8.1, cool silver
#  v3-572-78s3  acer aspire v3-572-78s3 15.6 notebook computer, intel core i7-4510u 2ghz, 8gb ram, 1tb hdd, windows 8.1, platinum silver
#  v3-572pg-767j acer aspire v3-572pg-767j 15.6 touchscreen notebook computer, intel core i7-4510u 2ghz, 8gb ram, 1tb hdd, windows 8.1, platinum silver
#  v7-482pg-5842  acer aspire v7-482pg-5842 14-inch touchscreen ultrabook cool steel computers accessories
#  v3-111p-43bc  acer aspire v3-111p-43bc 11.6-inch touchscreen laptop cool silver computers accessories
#  v3-772g-747a acer aspire v3-772g-747a121.12tbdcckk 17.3 led comfyview notebook - intel core i7 i7-4702mq 2.20 ghz - black 12 gb ram - 1 tb hdd - 120 gb ssd - blu-ray reader dvd-writer - nvidia geforce gtx 760m - windows 8 64-bit - 1920 x 1080 display - bluetooth price comparison at buy.net
#  v5-573p-5420 acer aspire v5-573p-54208g1taii 15.6 touchscreen led notebook - intel core i5 i5-4200u 1.60 ghz 8 gb ram - 1 tb hdd - intel hd 4400 - windows 8.1 64-bit - 1366 x 768 display - bluetooth price comparison at buy.net
#  v5-573p-5420 acer aspire v5-573p-54208g1tarr 15.6 touchscreen led notebook - intel core i5 i5-4200u 1.60 ghz - red 8 gb ram - 1 tb hdd - intel hd 4400 - windows 8.1 64-bit - 1366 x 768 display - bluetooth price comparison at buy.net
#  e1-572-6870   acer aspire e1-572-6870 15.6 inch laptop intel i5 4200u 1.6ghz processor, 4gb ram, 500gb hard drive, windows 8 clarinet black laptop computers computers accessories
#  e1-771-6496   acer aspire nx.mg7aa.005 e1-771-6496 17.3-inch laptop computers accessories
#  e3-111-c5gl   acer aspire e3-111-c5gl 11.6-inch laptop cool silver computers accessories
#  e1-771-6458   acer aspire nx.mg7aa.006 e1-771-6458 17.3-inch laptop computers accessories
#  e1-771-33116 acer aspire e1-771-33116g50mnii - 17.3 - core i3 3110m - windows 7 home premium 64-bit - 6 gb ram - 500 gb hdd
#  e5-771-37gd  acer aspire e5-771-37gd 17.3 notebook computer, intel core i3-4030u 1.8ghz processor, 4gb ram, 500gb hdd, windows 8.1, iron silver
#  e1-572-34014 acer aspire e1-572-34014g50mnkk - 15.6 - core i3 4010u - windows 7 home premium 64-bit - 4 gb ram - 500 gb hdd
#  e1-572-54204 acer aspire e1-572-54204g50mnrr - 15.6 - core i5 4200u - windows 7 home premium 64-bit - 4 gb ram - 500 gb hdd
#  e1-771-53236 acer aspire e1-771-53236g50mnii - 17.3 - core i5 3230m - windows 7 home premium 64-bit - 6 gb ram - 500 gb hdd
#  e1-572-54204 acer aspire e1-572-54204g50mnkk - 15.6 - core i5 4200u - windows 7 home premium 64-bit - 4 gb ram - 500 gb hdd
#  e1-572-34014 acer aspire e1-572-34014g50mnrr - 15.6 - core i3 4010u - windows 7 home premium 64-bit - 4 gb ram - 500 gb hdd
#  e1-731-20204 acer aspire e1-731-20204g50mnii - 17.3 - pentium 2020m - windows 7 home premium 64-bit - 4 gb ram - 500 gb hdd
#  e1-532-29574 acer aspire e1-532-29574g50mnrr - 15.6 - celeron 2957u - windows 7 home premium 64-bit - 4 gb ram - 500 gb hdd
#  e1-532-29574 acer aspire e1-532-29574g50mnkk - 15.6 - celeron 2957u - windows 7 home premium 64-bit - 4 gb ram - 500 gb hdd
#  e1-522-5423  acer aspire e1-522-5423 - 15.6 - a series a4-5000 - windows 8.1 64-bit - 4 gb ram - 500 gb hdd
#  e1-571-6607   lb1 high performance new acer black silver aspire e e1-571-6607 15.6 laptop pc with intel core i3-2348m processor 4gb memory 500gb hard drive and windows 7 home premium 64-bit high end professional audiophile wireless bluetooth mini speaker portable with built-in microphone and micro sd card slot silver computers accessories
#  e1-571-6607   lb1 high performance new acer black silver aspire e e1-571-6607 15.6 laptop pc with intel core i3-2348m processor 4gb memory 500gb hard drive and windows 7 home premium 64-bit high end professional audiophile wireless bluetooth mini speaker portable with built-in microphone and micro sd card slot silver computers accessories
#  e1-572-34014  brand new acer america corp. acer aspire e1-572-34014g50mnkk 15.6 led notebook - intel core i3 i3-4010u 1.70 ghz - black computers accessories
#  e5-771-37gd   acer aspire e5-771-37gd 17.3 notebook computer, intel core i3-4030u 1.8ghz processor, 4gb ram, 500gb hdd, windows 8.1, iron silver computers accessories
#  e1-571-6607   lb1 high performance new acer black silver aspire e e1-571-6607 15.6 laptop pc with intel core i3-2348m processor 4gb memory 500gb hard drive and windows 7 home premium 64-bit high end professional audiophile wireless bluetooth mini speaker with built-in microphone - micro sd card slot - voice prompt silver computers accessories
#  e1-572-34014  acer nx.m8eaa.007 aspire e1-572-34014g50mnkk 15.6 led notebook - intel core i3 i3-4010u 1.70 ghz - black 4 gb ram - 500 gb hdd - dvd-writer - intel hd 4400 graphics - windows 7 home premium 64-bit - 1366 x 768 display - bluetooth computers accessories
#  e1-572-34014  acer aspire e1-572-34014g50mnkk 15.6 led notebook - intel core i3 i3-4010u 1.70 ghz - black 4 gb ram - 500 gb hdd - dvd-writer - intel hd 4400 graphics - windows 7 home premium 64-bit - 1366 x 768 display - bluetooth nx.m8eaa.007 computers accessories
#  e5-571-30f1   acer aspire nx.mpsaa.002 e5-571-30f1 15.6-inch laptop computers accessories
#  e1-571-32344  acer aspire e1-571-32344g50mnks 15.6 led notebook - intel core i3 i3-2348m 2.30 ghz laptop computers computers accessories
#  e3-111-c5gl   acer aspire e3-111-c5gl 11.6-inch laptop cool silver computers accessories
#  e1-771-6458   acer aspire nx.mg7aa.006 e1-771-6458 17.3-inch laptop computers accessories
#  e1-572-6870   acer aspire e1-572-6870 15.6 inch laptop intel i5 4200u 1.6ghz processor, 4gb ram, 500gb hard drive, windows 8 clarinet black laptop computers computers accessories
#  e1-572-6484   acer aspire nx.mhfaa.002 e1-572-6484 15.6-inch laptop computers accessories
#  e1-572-34014  acer aspire e1-572-34014g50mnrr 15.6 led notebook intel core i3-4010u 1.70 ghz 4gb ddr3 500gb hdd dvd-writer intel hd graphics 4400 windows 7 home premium 64-bit red computers accessories
#  e1-771-33116  acer acer aspire e1-771-33116g50mnii - core i3 3110m 2.4 ghz - windows 7 home premium 64-bit - 6 gb ram - 500 gb hdd - dvd supermulti - 17.3 cinecrystal wide 1600 x 900 hd - intel hd graphics 4000 - iron imr - keyboard us international nx.mg7aa.006 computers accessories
#  e1-571-6607   lb1 high performance new wireless bluetooth mini speaker for acer black silver aspire e e1-571-6607 15.6 laptop pc with intel core i3-2348m processor 4gb memory 500gb hard drive and windows 7 home premium 64-bit with built-in microphone - micro sd card slot - voice prompt silver computers accessories
#  e1-571-6607,  acer aspire e1-571-6607, 16 - inch notebook windows 7 home premium 64-bit, intel core i3 2348m 2.30ghz 4gb memory 500gb hdd laptop computers computers accessories
#  e5-571-38kj   acer aspire nx.mltaa.011 e5-571-38kj 15.6-inch laptop computers accessories
#  e1-771-6603   acer aspire e1-771-6603 17.3-inch laptop 2.4 ghz intel core i3-3110m processor, 6gb ddr3, 750gb hdd, windows 8 steel gray laptop computers computers accessories
#  e1-572p-6468  acer aspire e1-572p-6468 16-inch touchscreen notebook 1.7ghz intel core i3-4010u, 4gb ram, 500gb hdd, windows 8.1 notebook computers computers accessories
#  e3-111-c5gl   acer aspire e3-111-c5gl 11.6-inch laptop cool silver computers accessories
#  e1-571-6607   lb1 high performance new wireless bluetooth mini speaker portable for acer black silver aspire e e1-571-6607 15.6 laptop pc with intel core i3-2348m processor 4gb memory 500gb hard drive and windows 7 home premium 64-bit with built-in microphone and micro sd card slot silver computers accessories
#  e1-572-34014  brand new acer america corp. acer aspire e1-572-34014g50mnrr 15.6 led notebook - intel core i3 i3-4010u 1.70 ghz - red computers accessories
#  e1-572-54204 acer aspire e1-572-54204g50mnrr 15.6 led notebook - intel core i5 i5-4200u 1.60 ghz - red 4 gb ram - 500 gb hdd - dvd-writer - intel hd 4400 - windows 7 home premium 64-bit - 1366 x 768 display - bluetooth price comparison at buy.net
#  e1-771-53236 acer aspire e1-771-53236g50mnii 17.3 led notebook - intel core i5 i5-3230m 2.60 ghz 6 gb ram - 500 gb hdd - dvd-writer - intel hd 4000 - windows 7 home premium 64-bit - 1600 x 900 display - bluetooth price comparison at buy.net
#  e1-532-29574 acer aspire e1-532-29574g50mnrr 15.6 led notebook - intel celeron 2957u 1.40 ghz - red 4 gb ram - 500 gb hdd - dvd-writer - intel hd graphics - windows 7 home premium 64-bit - 1366 x 768 display - bluetooth price comparison at buy.net
#  e1-572-34014 acer aspire e1-572-34014g50mnrr 15.6 led notebook - intel core i3 i3-4010u 1.70 ghz - red 4 gb ram - 500 gb hdd - dvd-writer - intel hd 4400 - windows 7 home premium 64-bit - 1366 x 768 display - bluetooth price comparison at buy.net
#  e1-532-29574 acer aspire e1-532-29574g50mnkk 15.6 led notebook - intel celeron 2957u 1.40 ghz - black 4 gb ram - 500 gb hdd - dvd-writer - intel hd graphics - windows 7 home premium 64-bit - 1366 x 768 display - bluetooth price comparison at buy.net
#  e1-731-20204 acer aspire e1-731-20204g50mnii 17.3 led notebook - intel pentium 2020m 2.40 ghz 4 gb ram - 500 gb hdd - dvd-writer - intel hd graphics - windows 7 home premium 64-bit - 1600 x 900 display - bluetooth price comparison at buy.net
#  e1-771-33116 acer aspire e1-771-33116g50mnii 17.3 led notebook - intel core i3 i3-3110m 2.40 ghz 6 gb ram - 500 gb hdd - dvd-writer - intel hd 4000 - windows 7 home premium 64-bit - 1600 x 900 display - bluetooth price comparison at buy.net
#  e1-522-45004 acer aspire e1-522-45004g50mnkk 15.6 led notebook - amd a-series a4-5000 1.50 ghz - black 4 gb ram - 500 gb hdd - dvd-writer - amd radeon hd 8330 - windows 8.1 64-bit - 1366 x 768 display - bluetooth price comparison at buy.net
#  e1-572-34014 acer aspire e1-572-34014g50mnkk 15.6 led notebook - intel core i3 i3-4010u 1.70 ghz - black 4 gb ram - 500 gb hdd - dvd-writer - intel hd 4400 - windows 7 home premium 64-bit - 1366 x 768 display - bluetooth price comparison at buy.net
#
# 61

# %%
asus_title = list(output[1].title)
asus_title
# Out:
# [' asus ux31a-xb52 13.3-inch ultrabook 1.7 ghz intel core i5-3317u processor, 4gb ddr3, 256gb ssd, windows 7 professional silver aluminum laptop computers computers accessories',
#  ' asus ux31a ux31a-xb52 13.3-inch laptop silver aluminum laptop computers computers accessories']

# %%
c = 0
regex = [r'\sux...-.....']
for r in regex:
    cr = re.compile(r)
    for t in asus_title:
        if re.search(cr, t):
            print(re.search(cr, t).group(), t)
            c+=1
print()
print(c)
# Out:
#  ux31a-xb52   asus ux31a-xb52 13.3-inch ultrabook 1.7 ghz intel core i5-3317u processor, 4gb ddr3, 256gb ssd, windows 7 professional silver aluminum laptop computers computers accessories
#  ux31a-xb52   asus ux31a ux31a-xb52 13.3-inch laptop silver aluminum laptop computers computers accessories
#
# 2

# %%
hp = ((list(output[3].title)))
list(output[3].title)
# Out:
# [' 15.6 hp 15-f009wm amd dual-core e1-2100 4gb ddr3 ram 500gb hd webcam windows 8.1 certified refurbished computers accessories',
#  ' hp 15-p030nr 15.6-inch special edition laptop with beats audio computers accessories',
#  'hp elitebook folio 9470m - 14 - core i5 3427u - windows 7 pro 64-bit - 4 gb ram - 500 gb hdd',
#  'hp elitebook folio 9470m - 14 - core i5 3427u - windows 7 pro 32-bit - 4 gb ram - 320 gb hdd',
#  'hp elitebook revolve 810 g2 tablet - 11.6 - core i3 4010u - windows 7 pro 64-bit windows 8.1 pro downgrade - 4 gb ram - 128 gb ssd',
#  'hp elitebook folio 9470m - 14 - core i5 3427u - windows 7 pro 64-bit - 8 gb ram - 320 gb hdd',
#  'hp elitebook revolve 810 g2 tablet - 11.6 - core i3 4010u - windows 7 pro 64-bit windows 8.1 pro downgrade - 4 gb ram - 128 gb ssd',
#  'hp elitebook folio 9470m - 14 - core i5 3427u - windows 7 pro - 8 gb ram - 180 gb ssd',
#  'hp elitebook revolve 810 g1 tablet - 11.6 - core i5 3437u - windows 8 pro 64-bit - 4 gb ram - 128 gb ssd',
#  'hp elitebook folio 9470m - 14 - core i5 3427u - windows 7 pro 32-bit - 4 gb ram - 180 gb ssd',
#  'hp elitebook folio 9470m - 14 - core i5 3427u - windows 7 pro 64-bit - 4 gb ram - 500 gb hdd',
#  'hp elitebook 2170p - 11.6 - core i5 3437u - windows 7 pro 64-bit - 4 gb ram - 128 gb ssd',
#  ' hp 15-p030nr 15.6-inch special edition laptop with beats audio computers accessories',
#  ' hp 15-series 15-f009wm laptop amd e1-2100 e1x2-1.0glv 4gb 1-dimm 500gb 5400rpm m computers accessories',
#  ' hp 15-series 15-f009wm laptop amd e1-2100 e1x2-1.0glv 4gb 1-dimm 500gb 5400rpm m computers accessories',
#  ' hp 15-d053cl touchsmart notebook 2.5ghz 3rd generation intel core i3-3120m processor 6gb ddr3l sdram 2 dimm 750gb 5400rpm hard drive computers accessories',
#  ' hp 15-p030nr 15.6-inch special edition laptop with beats audio computers accessories',
#  ' hp 15-d053cl touchsmart - 15.6 hd touchscreen notebook pc - intel core i3-3120m 6gb ddr3l sdram 750gb hdd windows 8.1 intel hd graphics 4000 wifi supermulti dvd burner webcam - black certified refurbished computers accessories',
#  'hp hewlett-packard elitebook 8560p 15.6 silver notebook 2.3 ghz intel core i5 2410m, 4 gb ddr3, 500 gb hdd, dvdrw dl, radeon hd 6470m, windows 7 professional, led backlight price comparison at buy.net',
#  'hp hewlett-packard elitebook revolve 810 g1 tablet pc - 11.6 - wireless lan - intel core i5 i5-3437u 1.90 ghz 4 gb ram - 128 gb ssd - windows 7 professional 64-bit - convertible - 1366 x 768 led backlight - bluetooth price comparison at buy.net',
#  'hp hewlett-packard elitebook revolve 810 g1 tablet pc - 11.6 - intel - core i5 i5-3437u 1.9ghz 4 gb ram - 128 gb ssd - windows 7 professional 64-bit - convertible - 1366 x 768 led backlight price comparison at buy.net',
#  'hp lq166aw elitebook 8460p 14 notebook - vology',
#  'hp c7a50ut elitebook 2170p 11.6 notebook - vology',
#  'hp c6z63ut elitebook folio 9470m 14 ultrabook - vology',
#  'hp lq589aw elitebook 8560p 15.6 notebook - vology',
#  'hp c6z61ut elitebook folio 9470m 14 ultrabook - vology',
#  'hp c6z56ut elitebook 8570p 15.6 notebook - vology',
#  'hp b8s45aw elitebook 2570p 12.5 notebook - vology',
#  'hp b8v39ut elitebook 8570p 15.6 notebook - vology',
#  'hp xu066ua elitebook 8560p 15.6 notebook - vology',
#  'hp lj549ut elitebook 8560p 15.6 notebook - vology',
#  'hp lx389aw elitebook 2760p 12.1 tablet notebook - vology',
#  'hp b8s43aw elitebook 2570p 12.5 notebook - vology',
#  'hp lq168aw elitebook 8460p 14 notebook - vology',
#  'hp lj466ut elitebook 2760p 12.1 tablet notebook - vology',
#  'hp c6z58ut elitebook 8570p 15.6 notebook - vology',
#  'hp b8j91aw elitebook 2170p 11.6 notebook - vology']

# %%
lenovo = (list(output[4].title))
print(len(lenovo))
# lenovo
# Out:
# 234

# %%
c = 0
regex = [r'\sx\d{3}\s?tablet?\s?\d{0,4}', r'\sx\d{3}\s?laptop?\s?\d{0,4}', r'\sx\d{3}\s?\d{0,4}',r'\sx\d{1}\scarbon\s\d{4}', r'\sx\d{1}\scarbon touch\s\d{4}']
for t in lenovo:
    found = False
    for r in regex: 
        cr = re.compile(r)
        if re.search(cr, t):
            print(re.search(cr, t).group(), "___", t[:50])
            c+=1
            found = True
            break
    if not found:
        print(t)
    
print()
print(c)
# Out:
#  x230 3435 ___ lenovo thinkpad x230 34352jf tablet pc - 12.5 - in
#  x201 tablet 3093 ___  lenovo 3093b51 thinkpad x201 tablet 3093 - conver
#  x201 tablet 3093 ___  lenovo 3093b65 thinkpad x201 tablet 3093 - conver
#  x230 laptop  ___  lenovo thinkpad x230 laptop - 2325t11 - 12.5 ultr
#  x1 carbon 3444 ___ lenovo thinkpad x1 carbon 3444 - 14 - core i7 3667
#  x230 tablet 3435 ___ lenovo thinkpad x230 tablet 3435 - 12.5 - core i5
#  x230 tablet 3437 ___ lenovo thinkpad x230 tablet 3437 - 12.5 - core i5
#  x230 2320 ___ lenovo thinkpad x230 2320 - 12.5 - core i5 3210m -
#  x230 tablet 3435 ___ lenovo thinkpad x230 tablet 3435 - 12.5 - core i5
#  x230 ___ lenovo thinkpad x230t 3435-22u tablet pc - 3rd gen
#  x130 ___  lenovo thinkpad x130e 2338 - 11.6 - core i3 2367m
#  x1 carbon 3460 ___ lenovo x1 carbon 346058u 14 led ultrabook - intel
#  x230 3435 ___ lenovo x230 34352ju tablet pc - 12.5 - in-plane sw
#  x130 ___ lenovo thinkpad x130e 2339 - 11.6 - core i3 2367m
#  x230 2324 ___ lenovo thinkpad x230 2324 - 12.5 - core i5 3320m -
#  x1 carbon 3448 ___ lenovo thinkpad x1 carbon 3448 - 14 - core i7 3667
#  x230 tablet 3438 ___ lenovo thinkpad x230 tablet 3438 - 12.5 - core i5
#  x230 2320 ___ lenovo thinkpad x230 2320 - 12.5 - core i5 3210m -
#  x1 carbon 3460 ___ lenovo thinkpad x1 carbon 3460 - 14 - core i7 3667
#  x230 2324 ___ lenovo thinkpad x230 2324 - 12.5 - core i5 3320m -
#  x230 2320 ___ lenovo thinkpad x230 2320 - 12.5 - core i7 3520m -
#  x230 tablet 3435 ___ lenovo thinkpad x230 tablet 3435 - 12.5 - core i5
#  x1 carbon 3444 ___ lenovo thinkpad x1 carbon 3444 - 14 - core i7 3667
#  x230 2324 ___ lenovo thinkpad x230 2324 - 12.5 - core i5 3360m -
#  x230 2320 ___ lenovo thinkpad x230 2320 - 12.5 - core i5 3320m -
#  x230 2324 ___ lenovo thinkpad x230 2324 - 12.5 - core i5 3320m -
#  x1 carbon 3460 ___ lenovo thinkpad x1 carbon 3460 - 14 - core i7 3667
#  x1 carbon touch 3448 ___ lenovo thinkpad x1 carbon touch 3448 - 14 - core i
#  x1 carbon touch 3460 ___ lenovo thinkpad x1 carbon touch 3460 - 14 - core i
#  x230 tablet 3438 ___ lenovo thinkpad x230 tablet 3438 - 12.5 - core i5
#  x1 carbon touch 3448 ___ lenovo thinkpad x1 carbon touch 3448 - 14 - core i
#  x230 tablet 3438 ___ lenovo thinkpad x230 tablet 3438 - 12.5 - core i5
#  x230 tablet 3437 ___ lenovo thinkpad x230 tablet 3437 - 12.5 - core i5
#  x230 2324 ___ lenovo thinkpad x230 2324 - 12.5 - core i5 3320m -
#  x1 carbon 3460 ___ lenovo thinkpad x1 carbon 3460 - 14 - core i5 3427
#  x230 tablet 3438 ___ lenovo thinkpad x230 tablet 3438 - 12.5 - core i5
#  x1 carbon 3460 ___ lenovo thinkpad x1 carbon 3460 - 14 - core i5 3427
#  x230 tablet 3437 ___ lenovo thinkpad x230 tablet 3437 - 12.5 - core i5
#  x230 2324 ___ lenovo thinkpad x230 2324 - 12.5 - core i5 3320m -
#  x1 carbon 3460 ___ lenovo thinkpad x1 carbon 3460 - 14 - core i5 3427
#  x230 2324 ___ lenovo thinkpad x230 2324 - 12.5 - core i5 3320m -
#  x230 2324 ___ lenovo thinkpad x230 2324 - 12.5 - core i5 3320m -
#  x220 4291 ___ lenovo thinkpad x220 4291 - 12.5 - core i5 2540m -
#  x1 carbon 3460 ___ lenovo thinkpad x1 carbon 3460 - 14 - core i7 3667
#  x230 2325 ___ lenovo thinkpad x230 2325 - 12.5 - core i5 3320m -
#  x230 2325 ___ lenovo thinkpad x230 2325 - 12.5 - core i5 3320m -
#  x230 2320 ___ lenovo thinkpad x230 2320 - 12.5 - core i5 3320m -
#  x230 2324 ___ lenovo thinkpad x230 2324 - 12.5 - core i5 3360m -
#  x1 carbon 3460 ___ lenovo thinkpad x1 carbon 3460 - 14 - core i5 3427
#  x230 2324 ___ lenovo thinkpad x230 2324 - 12.5 - core i5 3320m -
#  x130 ___ lenovo thinkpad x130e 0622 - 11.6 - e-300 - window
#  x1 carbon 3460 ___ lenovo thinkpad x1 carbon 3460 - 14 - core i5 3427
#  x230 tablet 3438 ___ lenovo thinkpad x230 tablet 3438 - 12.5 - core i5
#  x230 2325 ___ lenovo thinkpad x230 2325 - 12.5 - core i5 3320m -
#  x220 4290 ___ lenovo thinkpad x220 4290 - 12.5 - vology
#  x230 2324 ___ lenovo thinkpad x230 2324 - 12.5 - core i5 3320m -
#  x230 2325 ___ lenovo thinkpad x230 2325 - 12.5 - core i5 3320m -
#  x230 2324 ___ lenovo thinkpad x230 2324 - 12.5 - core i5 3320m -
#  x230 2325 ___ lenovo thinkpad x230 2325 - 12.5 - core i5 3320m -
#  x230 2325 ___ lenovo thinkpad x230 2325 - 12.5 - core i5 3320m -
#  x230 2324 ___ lenovo thinkpad x230 2324 - 12.5 - core i5 3320m -
#  x1 carbon 3448 ___ lenovo thinkpad x1 carbon 3448 - 14 - core i7 3667
#  x1 carbon touch 3448 ___ lenovo thinkpad x1 carbon touch 3448 - 14 - core i
#  x1 carbon 3460 ___ lenovo thinkpad x1 carbon 3460 - 14 - core i5 3427
#  x230 2325 ___ lenovo thinkpad x230 2325 - 12.5 - core i5 3320m -
#  x1 carbon touch 3444 ___ lenovo thinkpad x1 carbon touch 3444 - 14 - core i
#  x1 carbon 3460 ___ lenovo thinkpad x1 carbon 3460 - 14 - core i7 3667
#  x230 tablet 3435 ___ lenovo thinkpad x230 tablet 3435 - 12.5 - core i5
#  x230 2324 ___ lenovo thinkpad x230 2324 - 12.5 - core i5 3320m -
#  x230 tablet 3438 ___ lenovo thinkpad x230 tablet 3438 - 12.5 - core i5
#  x1 carbon 3448 ___ lenovo thinkpad x1 carbon 3448 - 14 - core i7 3667
#  x1 carbon touch 3460 ___ lenovo thinkpad x1 carbon touch 3460 - 14 - core i
#  x230 2320 ___ lenovo thinkpad x230 2320 - 12.5 - core i5 3320m -
#  x230 2320 ___ lenovo thinkpad x230 2320 - 12.5 - core i5 3210m -
#  x230 2320 ___ lenovo thinkpad x230 2320 - 12.5 - core i5 3320m -
#  x230 tablet 3437 ___ lenovo thinkpad x230 tablet 3437 - 12.5 - core i5
#  x230 tablet 3435 ___ lenovo thinkpad x230 tablet 3435 - 12.5 - core i7
#  x230 2324 ___ lenovo thinkpad x230 2324 - 12.5 - core i5 3320m -
#  x230 tablet 3438 ___ lenovo thinkpad x230 tablet 3438 - 12.5 - core i7
#  x230 tablet 3438 ___ lenovo thinkpad x230 tablet 3438 - 12.5 - core i7
#  x230 2324 ___ lenovo thinkpad x230 2324 - 12.5 - core i5 3320m -
#  x230 tablet 3435 ___ lenovo thinkpad x230 tablet 3435 - 12.5 - core i5
#  x1 carbon 3460 ___ lenovo thinkpad x1 carbon 3460 - 14 - core i7 3667
#  x1 carbon touch 3460 ___ lenovo thinkpad x1 carbon touch 3460 - 14 - core i
#  x230 2325 ___ lenovo thinkpad x230 2325 - 12.5 - core i5 3320m -
#  x230 tablet 3435 ___ lenovo thinkpad x230 tablet 3435 - 12.5 - core i7
#  x230 tablet 3438 ___ lenovo thinkpad x230 tablet 3438 - 12.5 - core i7
#  x230 2325 ___ lenovo thinkpad x230 2325 - 12.5 - core i5 3320m -
#  x230 2320 ___ lenovo thinkpad x230 2320 - 12.5 - core i5 3320m -
#  x230 2325 ___ lenovo thinkpad x230 2325 - 12.5 - core i5 3320m -
#  x230 2324 ___ lenovo thinkpad x230 2324 - 12.5 - core i5 3320m -
#  x1 carbon touch 3448 ___ lenovo thinkpad x1 carbon touch 3448 - 14 - core i
#  x1 carbon touch 3460 ___ lenovo thinkpad x1 carbon touch 3460 - 14 - core i
#  x230 2324 ___ lenovo thinkpad x230 2324 - 12.5 - core i5 3360m -
#  x230 2325 ___ lenovo thinkpad x230 2325 - 12.5 - core i5 3320m -
#  x230 2320 ___ lenovo thinkpad x230 2320 - 12.5 - core i5 3320m -
#  x230 tablet 3437 ___ lenovo thinkpad x230 tablet 3437 - 12.5 - core i5
#  x230 2325 ___ lenovo thinkpad x230 2325 - 12.5 - core i5 3320m -
#  x1 carbon 3448 ___ lenovo thinkpad x1 carbon 3448 - 14 - core i7 3667
#  x1 carbon 3460 ___ lenovo thinkpad x1 carbon 3460 - 14 - core i5 3427
#  x1 carbon touch 3460 ___ lenovo thinkpad x1 carbon touch 3460 - 14 - core i
#  x230 2325 ___ lenovo thinkpad x230 2325 - 12.5 - core i5 3320m -
#  x230 2325 ___ lenovo thinkpad x230 2325 - 12.5 - core i5 3320m -
#  x1 carbon 3444 ___ lenovo thinkpad x1 carbon 3444 - 14 - core i7 3667
#  x130 ___ lenovo thinkpad x130e 2338 - 11.6 - core i3 2367m
#  x230 2324 ___ lenovo thinkpad x230 2324 - 12.5 - core i5 3320m -
#  x130 ___ lenovo thinkpad x130e 0622 - 11.6 - e-450 - window
#  x230 tablet 3437 ___ lenovo thinkpad x230 tablet 3437 - 12.5 - core i5
#  x1 carbon 3460 ___ lenovo thinkpad x1 carbon 3460 - 14 - core i5 3427
#  x1 carbon touch 3460 ___ lenovo thinkpad x1 carbon touch 3460 - 14 - core i
#  x1 carbon touch 3460 ___ lenovo thinkpad x1 carbon touch 3460 - 14 - core i
#  x230 2324 ___ lenovo thinkpad x230 2324 - 12.5 - core i5 3320m -
#  x130 ___ lenovo thinkpad x130e 0627 - 11.6 - e-300 - window
#  x230 2325 ___ lenovo thinkpad x230 2325 - 12.5 - core i5 3360m -
#  x230 tablet 3435 ___ lenovo thinkpad x230 tablet 3435 - 12.5 - core i5
#  x220 4291 ___ lenovo thinkpad x220 4291 - 12.5 - core i5 2540m -
#  x1 carbon 3448 ___ lenovo thinkpad x1 carbon 3448 - 14 - core i7 3667
#  x1 carbon 3444 ___ lenovo thinkpad x1 carbon 3444 - 14 - core i7 3667
#  x230 tablet 3437 ___ lenovo thinkpad x230 tablet 3437 - 12.5 - core i5
#  x230 2320 ___ lenovo thinkpad x230 2320 - 12.5 - core i7 3520m -
#  x1 carbon touch 3460 ___ lenovo thinkpad x1 carbon touch 3460 - 14 - core i
#  x230 2324 ___ lenovo thinkpad x230 2324 - 12.5 - core i5 3320m -
#  x230 2324 ___ lenovo thinkpad x230 2324 - 12.5 - core i5 3320m -
#  x1 carbon 3444 ___ lenovo thinkpad x1 carbon 3444 - 14 - core i7 3667
#  x1 carbon 3460 ___ lenovo thinkpad x1 carbon 3460 - 14 - core i5 3427
#  x1 carbon 3448 ___ lenovo thinkpad x1 carbon 3448 - 14 - core i7 3667
#  x1 carbon 3448 ___ lenovo thinkpad x1 carbon 3448 - 14 - core i7 3667
#  x1 carbon 3460 ___ lenovo thinkpad x1 carbon 3460 - 14 - core i5 3427
#  x230 2320 ___ lenovo thinkpad x230 2320 - 12.5 - core i5 3320m -
#  x1 carbon 3444 ___ lenovo thinkpad x1 carbon 3444 - 14 - core i7 3667
#  x230 tablet 3437 ___ lenovo thinkpad x230 tablet 3437 - 12.5 - core i5
#  x1 carbon 3448 ___ lenovo thinkpad x1 carbon 3448 - 14 - core i7 3667
#  x230 2320 ___ lenovo thinkpad x230 2320 - 12.5 - core i5 3320m -
#  x230 2325 ___ lenovo thinkpad x230 2325 - 12.5 - core i5 3360m -
#  x230 2320 ___ lenovo thinkpad x230 2320 - 12.5 - core i7 3520m -
#  x1 carbon touch 3460 ___ lenovo thinkpad x1 carbon touch 3460 - 14 - core i
#  x230 2325 ___ lenovo thinkpad x230 2325 - 12.5 - core i5 3320m -
#  x130 ___ lenovo thinkpad x130e 0627 - 11.6 - e-450 - window
#  x1 carbon 3460 ___ lenovo thinkpad x1 carbon 3460 - 14 - core i5 3427
#  x130 ___ lenovo thinkpad x130e 2338 - 11.6 - core i3 2367m
#  x230 2320 ___ lenovo thinkpad x230 2320 - 12.5 - core i5 3320m -
#  x230 2324 ___ lenovo thinkpad x230 2324 - 12.5 - core i5 3320m -
#  x230 2325 ___ lenovo thinkpad x230 2325 - 12.5 - core i5 3320m -
#  x130 ___ lenovo thinkpad x130e 2338 - 11.6 - core i3 2367m
#  x230 tablet 3435 ___ lenovo thinkpad x230 tablet 3435 - 12.5 - core i5
#  x230 2324 ___ lenovo thinkpad x230 2324 - 12.5 - core i5 3320m -
#  x1 carbon 3460 ___ lenovo thinkpad x1 carbon 3460 - 14 - core i5 3427
#  x230 tablet 3437 ___ lenovo thinkpad x230 tablet 3437 - 12.5 - core i5
#  x230 tablet 3435 ___ lenovo thinkpad x230 tablet 3435 - 12.5 - core i7
#  x1 carbon 3444 ___ lenovo thinkpad x1 carbon 3444 - 14 - core i7 3667
#  x230 2320 ___ lenovo thinkpad x230 2320 - 12.5 - core i7 3520m -
#  x230 2324 ___ lenovo thinkpad x230 2324 - 12.5 - core i5 3320m -
#  x1 carbon 3444 ___ lenovo thinkpad x1 carbon 3444 - 14 - core i7 3667
#  x230 tablet 3435 ___ lenovo thinkpad x230 tablet 3435 - 12.5 - core i5
#  x220 4287 ___ lenovo thinkpad x220 4287 - 12.5 - with ultrabase
#  x230 tablet 3435 ___ lenovo thinkpad x230 tablet 3435 - 12.5 - core i7
#  x230 2325 ___ lenovo thinkpad x230 2325 - 12.5 - core i5 3320m -
#  x1 carbon 3460 ___ lenovo thinkpad x1 carbon 3460 - 14 - core i7 3667
#  x230 2320 ___ lenovo thinkpad x230 2320 - 12.5 - core i5 3320m -
#  x220 4290 ___ lenovo thinkpad x220 4290 - 12.5 - core i5 2540m -
#  x1 carbon 3444 ___ lenovo thinkpad x1 carbon 3444 - 14 - core i7 3667
#  x230 tablet 3438 ___ lenovo thinkpad x230 tablet 3438 - 12.5 - core i5
#  x230 2324 ___ lenovo thinkpad x230 2324 - 12.5 - core i5 3320m -
#  x230 tablet 3437 ___ lenovo thinkpad x230 tablet 3437 - 12.5 - core i5
#  x230 2320 ___ lenovo thinkpad x230 2320 - 12.5 - core i7 3520m -
#  x230 tablet 3435 ___ lenovo thinkpad x230 tablet 3435 - 12.5 - core i5
#  x230 2325 ___ lenovo thinkpad x230 2325 - 12.5 - core i5 3320m -
#  x1 carbon touch 3460 ___ lenovo thinkpad x1 carbon touch 3460 - 14 - core i
#  x1 carbon 3460 ___ lenovo thinkpad x1 carbon 3460 - 14 - core i5 3427
#  x230 2324 ___ lenovo thinkpad x230 2324 - 12.5 - core i5 3320m -
#  x1 carbon 3448 ___ lenovo thinkpad x1 carbon 3448 - 14 - core i7 3667
#  x230 2324 ___ lenovo thinkpad x230 2324 - 12.5 - core i5 3320m -
#  x230 tablet 3437 ___ lenovo thinkpad x230 tablet 3437 - 12.5 - core i5
#  x230 2325 ___ lenovo thinkpad x230 2325 - 12.5 - core i5 3320m -
#  x230 tablet 3438 ___ lenovo thinkpad x230 tablet 3438 - 12.5 - core i5
#  x230 tablet 3435 ___ lenovo thinkpad x230 tablet 3435 - 12.5 - core i5
#  x220 4291 ___ lenovo thinkpad x220 4291 - 12.5 - core i5 2540m -
#  x230 tablet 3435 ___ lenovo thinkpad x230 tablet 3435 - 12.5 - core i7
#  x1 carbon touch 3444 ___ lenovo thinkpad x1 carbon touch 3444 - 14 - core i
#  x1 carbon 3460 ___ lenovo thinkpad x1 carbon 3460 - 14 - core i7 3667
#  x230 tablet 3435 ___ lenovo thinkpad x230 tablet 3435 - 12.5 - core i7
#  x230 tablet 3435 ___ lenovo thinkpad x230 tablet 3435 - 12.5 - core i5
#  x120 ___ lenovo thinkpad x120e 0596 - 11.6 - e-350 - window
#  x130 ___ lenovo thinkpad x130e 2339 - 11.6 - core i3 2367m
#  x230 2325 ___ lenovo thinkpad x230 2325 - 12.5 - core i5 3320m -
#  x1 carbon 3444 ___ lenovo thinkpad x1 carbon 3444 - 14 - core i7 3667
#  x230 2324 ___ lenovo thinkpad x230 2324 - 12.5 - core i5 3320m -
#  x230 tablet 3437 ___ lenovo thinkpad x230 tablet 3437 - 12.5 - core i5
#  x1 carbon touch 3460 ___ lenovo thinkpad x1 carbon touch 3460 - 14 - core i
#  x1 carbon 3460 ___ lenovo thinkpad x1 carbon 3460 - 14 - core i5 3427
#  x230 2324 ___ lenovo thinkpad x230 2324 - 12.5 - core i5 3360m -
#  x230 2324 ___ lenovo thinkpad x230 2324 - 12.5 - core i5 3320m -
#  x230 tablet 3438 ___ lenovo thinkpad x230 tablet 3438 - 12.5 - core i5
#  x1 carbon touch 3460 ___ lenovo thinkpad x1 carbon touch 3460 - 14 - core i
#  x1 carbon 3460 ___ lenovo thinkpad x1 carbon 3460 - 14 - core i7 3667
#  x230 2320 ___ lenovo thinkpad x230 2320 - 12.5 - core i7 3520m -
#  x230 2325 ___ lenovo thinkpad x230 2325 - 12.5 - core i5 3320m -
#  x1 carbon 3444 ___ lenovo thinkpad x1 carbon 3444 - 14 - core i7 3667
#  x230 2325 ___ lenovo thinkpad x230 2325 - 12.5 - core i5 3320m -
#  x230 2325 ___ lenovo thinkpad x230 2325 - 12.5 - core i5 3320m -
#  x220 4290 ___ lenovo thinkpad x220 4290 - 12.5 - core i5 2540m -
#  x230 2325 ___ lenovo thinkpad x230 2325 - 12.5 - core i5 3320m -
#  x1 carbon 3448 ___ lenovo thinkpad x1 carbon 3448 - 14 - core i7 3667
#  x230 2320 ___ lenovo thinkpad x230 2320 - 12.5 - core i5 3320m -
#  x120 ___ lenovo thinkpad x120e 0596 - 11.6 - e-350 - window
#  x1 carbon 3460 ___ lenovo thinkpad x1 carbon 3460 - 14 - core i5 3427
#  x1 carbon 3460 ___ lenovo thinkpad x1 carbon 3460 - 14 - core i7 3667
#  x1 carbon 3460 ___ lenovo thinkpad x1 carbon 3460 - 14 - core i7 3667
#  x1 carbon 3460 ___ lenovo thinkpad x1 carbon 3460 - 14 - core i5 3427
#  x230 tablet 3435 ___ lenovo thinkpad x230 tablet 3435 - 12.5 - core i7
#  x1 carbon 3444 ___ lenovo thinkpad x1 carbon 3444 - 14 - core i7 3667
#  x220 4291 ___ lenovo thinkpad x220 4291 - 12.5 - vology
#  x1 carbon touch 3460 ___ lenovo thinkpad x1 carbon touch 3460 - 14 - core i
#  x130 ___ lenovo thinkpad x130e 2339 - 11.6 - core i3 2367m
#  x230 2320 ___ lenovo thinkpad x230 2320 - 12.5 - core i5 3320m -
#  x1 carbon 3448 ___ lenovo thinkpad x1 carbon 3448 - 14 - core i7 3667
#  x230 2325 ___ lenovo thinkpad x230 2325 - 12.5 - core i5 3320m -
#  x230 2320 ___ lenovo thinkpad x230 2320 - 12.5 - core i5 3320m -
#  x230 2325 ___ lenovo thinkpad x230 2325 - 12.5 - core i5 3320m -
#  x1 carbon 3444 ___ lenovo thinkpad x1 carbon 3444 - 14 - core i7 3667
#  x230 2320 ___ lenovo thinkpad x230 2320 - 12.5 - core i5 3320m -
#  x1 carbon touch 3444 ___ lenovo thinkpad x1 carbon touch 3444 - 14 - core i
#  x1 carbon 3444 ___ lenovo thinkpad x1 carbon 3444 - 14 - core i7 3667
#  x1 carbon 3444 ___ lenovo thinkpad x1 carbon 3444 - 14 - core i7 3667
#  x230 tablet 3438 ___ lenovo thinkpad x230 tablet 3438 - 12.5 - core i5
#  x230 2320 ___ lenovo thinkpad x230 2320 - 12.5 - core i5 3210m -
#  x230 2324 ___ lenovo thinkpad x230 2324 - 12.5 - core i5 3320m -
#  x230 2324 ___ lenovo thinkpad x230 2324 - 12.5 - core i5 3320m -
#  x230 2320 ___ lenovo thinkpad x230 2320 - 12.5 - core i5 3320m -
#  x230 2320 ___ lenovo thinkpad x230 2320 - 12.5 - core i5 3320m -
#  x230 2325 ___ lenovo thinkpad x230 2325 - 12.5 - core i5 3320m -
#  x230 tablet 3438 ___ lenovo thinkpad x230 tablet 3438 - 12.5 - core i5
#  x230 2324 ___ lenovo thinkpad x230 2324 - 12.5 - core i5 3320m -
#  x230 2320 ___ lenovo thinkpad x230 2320 - 12.5 - core i7 3520m -
#
# 234

# %%
print(len(hp))
hp
# Out:
# 37
# [' 15.6 hp 15-f009wm amd dual-core e1-2100 4gb ddr3 ram 500gb hd webcam windows 8.1 certified refurbished computers accessories',
#  ' hp 15-p030nr 15.6-inch special edition laptop with beats audio computers accessories',
#  'hp elitebook folio 9470m - 14 - core i5 3427u - windows 7 pro 64-bit - 4 gb ram - 500 gb hdd',
#  'hp elitebook folio 9470m - 14 - core i5 3427u - windows 7 pro 32-bit - 4 gb ram - 320 gb hdd',
#  'hp elitebook revolve 810 g2 tablet - 11.6 - core i3 4010u - windows 7 pro 64-bit windows 8.1 pro downgrade - 4 gb ram - 128 gb ssd',
#  'hp elitebook folio 9470m - 14 - core i5 3427u - windows 7 pro 64-bit - 8 gb ram - 320 gb hdd',
#  'hp elitebook revolve 810 g2 tablet - 11.6 - core i3 4010u - windows 7 pro 64-bit windows 8.1 pro downgrade - 4 gb ram - 128 gb ssd',
#  'hp elitebook folio 9470m - 14 - core i5 3427u - windows 7 pro - 8 gb ram - 180 gb ssd',
#  'hp elitebook revolve 810 g1 tablet - 11.6 - core i5 3437u - windows 8 pro 64-bit - 4 gb ram - 128 gb ssd',
#  'hp elitebook folio 9470m - 14 - core i5 3427u - windows 7 pro 32-bit - 4 gb ram - 180 gb ssd',
#  'hp elitebook folio 9470m - 14 - core i5 3427u - windows 7 pro 64-bit - 4 gb ram - 500 gb hdd',
#  'hp elitebook 2170p - 11.6 - core i5 3437u - windows 7 pro 64-bit - 4 gb ram - 128 gb ssd',
#  ' hp 15-p030nr 15.6-inch special edition laptop with beats audio computers accessories',
#  ' hp 15-series 15-f009wm laptop amd e1-2100 e1x2-1.0glv 4gb 1-dimm 500gb 5400rpm m computers accessories',
#  ' hp 15-series 15-f009wm laptop amd e1-2100 e1x2-1.0glv 4gb 1-dimm 500gb 5400rpm m computers accessories',
#  ' hp 15-d053cl touchsmart notebook 2.5ghz 3rd generation intel core i3-3120m processor 6gb ddr3l sdram 2 dimm 750gb 5400rpm hard drive computers accessories',
#  ' hp 15-p030nr 15.6-inch special edition laptop with beats audio computers accessories',
#  ' hp 15-d053cl touchsmart - 15.6 hd touchscreen notebook pc - intel core i3-3120m 6gb ddr3l sdram 750gb hdd windows 8.1 intel hd graphics 4000 wifi supermulti dvd burner webcam - black certified refurbished computers accessories',
#  'hp hewlett-packard elitebook 8560p 15.6 silver notebook 2.3 ghz intel core i5 2410m, 4 gb ddr3, 500 gb hdd, dvdrw dl, radeon hd 6470m, windows 7 professional, led backlight price comparison at buy.net',
#  'hp hewlett-packard elitebook revolve 810 g1 tablet pc - 11.6 - wireless lan - intel core i5 i5-3437u 1.90 ghz 4 gb ram - 128 gb ssd - windows 7 professional 64-bit - convertible - 1366 x 768 led backlight - bluetooth price comparison at buy.net',
#  'hp hewlett-packard elitebook revolve 810 g1 tablet pc - 11.6 - intel - core i5 i5-3437u 1.9ghz 4 gb ram - 128 gb ssd - windows 7 professional 64-bit - convertible - 1366 x 768 led backlight price comparison at buy.net',
#  'hp lq166aw elitebook 8460p 14 notebook - vology',
#  'hp c7a50ut elitebook 2170p 11.6 notebook - vology',
#  'hp c6z63ut elitebook folio 9470m 14 ultrabook - vology',
#  'hp lq589aw elitebook 8560p 15.6 notebook - vology',
#  'hp c6z61ut elitebook folio 9470m 14 ultrabook - vology',
#  'hp c6z56ut elitebook 8570p 15.6 notebook - vology',
#  'hp b8s45aw elitebook 2570p 12.5 notebook - vology',
#  'hp b8v39ut elitebook 8570p 15.6 notebook - vology',
#  'hp xu066ua elitebook 8560p 15.6 notebook - vology',
#  'hp lj549ut elitebook 8560p 15.6 notebook - vology',
#  'hp lx389aw elitebook 2760p 12.1 tablet notebook - vology',
#  'hp b8s43aw elitebook 2570p 12.5 notebook - vology',
#  'hp lq168aw elitebook 8460p 14 notebook - vology',
#  'hp lj466ut elitebook 2760p 12.1 tablet notebook - vology',
#  'hp c6z58ut elitebook 8570p 15.6 notebook - vology',
#  'hp b8j91aw elitebook 2170p 11.6 notebook - vology']

# %%
c = 0
regex = [r'\sfolio\s?\d{4}.', r'\selitebook\s?\d{4}.', r'\s\d{2}-.{4,6}']
for t in hp:
    found = False
    for r in regex: 
        cr = re.compile(r)
        if re.search(cr, t):
            print(re.search(cr, t).group())
            c+=1
            found = True
            break
    if not found:
        print(t)    
print()
print(c)
# Out:
#  15-f009wm
#  15-p030nr
#  folio 9470m
#  folio 9470m
#  64-bit wi
#  folio 9470m
#  64-bit wi
#  folio 9470m
#  64-bit -
#  folio 9470m
#  folio 9470m
#  elitebook 2170p
#  15-p030nr
#  15-series
#  15-series
#  15-d053cl
#  15-p030nr
#  15-d053cl
#  elitebook 8560p
#  64-bit -
#  64-bit -
#  elitebook 8460p
#  elitebook 2170p
#  folio 9470m
#  elitebook 8560p
#  folio 9470m
#  elitebook 8570p
#  elitebook 2570p
#  elitebook 8570p
#  elitebook 8560p
#  elitebook 8560p
#  elitebook 2760p
#  elitebook 2570p
#  elitebook 8460p
#  elitebook 2760p
#  elitebook 8570p
#  elitebook 2170p
#
# 37

# %%
dell = ((list(output[2].title)))
print(len(dell))
dell
# Out:
# 9
# [' dell inspiron i5547-5780slv 15.6-inch laptop computers accessories',
#  ' dell inspiron m731r 18-inch hd notebook amd quad-core a8-5545m 1.7ghz processor, 8gb ram, 1tb hard drive, windows 8.1 indigo blue computers accessories',
#  ' dell inspiron i5547-15001slv 15.6-inch touchscreen laptop computers accessories',
#  ' dell inspiron i5547-3753slv 15.6-inch laptop 1.7 ghz intel core i5-4210u processor, 6gb ddr3, 1tb hdd, windows 8.1 silver computers accessories',
#  ' dell inspiron i5547-3751slv 16-inch touchscreen laptop 1.70 ghz intel core i5-4210u processor, 6gb memory, 1tb hard drive, win 8.1 computers accessories',
#  ' dell inspiron i5547-3751slv 16-inch touchscreen laptop 1.70 ghz intel core i5-4210u processor, 6gb memory, 1tb hard drive, win 8.1 computers accessories',
#  ' dell inspiron i5547-15001slv 15.6-inch touchscreen laptop computers accessories',
#  ' dell inspiron i5547-5780slv 15.6-inch laptop computers accessories',
#  ' dell inspiron m731r 18-inch hd notebook amd quad-core a8-5545m 1.7ghz processor, 8gb ram, 1tb hard drive, windows 8.1 indigo blue computers accessories']

# %%
c = 0
regex = [r'\s[nmi]\d{3,4}(-\d{4})?']
for t in dell:
    found = False
    for r in regex: 
        cr = re.compile(r)
        if re.search(cr, t):
            print(re.search(cr, t).group())
            c+=1
            found = True
            break
    if not found:
        print(t)    
print()
print(c)
# Out:
#  i5547-5780
#  m731
#  i5547-1500
#  i5547-3753
#  i5547-3751
#  i5547-3751
#  i5547-1500
#  i5547-5780
#  m731
#
# 9

# %%
# Read the X2 dataset and see what else can we get from just 
x3_org = pd.read_csv('../data/sigmod/X3.csv')

# Current cleaning output
x3_dev = clean_laptops_dataset(x3_org)

# %%
grouped = x3_dev.groupby(['brand'])
output = []
for g in grouped.groups.keys():
    output.append(x3_dev.loc[grouped.groups[g]])
print("Number of groups", len(output))
# Out:
# Number of groups 5

# %%
output[0]
# Out:
#                  instance_id brand cpu_brand  \
# instance_id
# source7__1731  source7__1731  acer     intel
# source7__1655  source7__1655  acer     intel
# source1__130    source1__130  acer       amd
# source1__112    source1__112  acer     intel
# source6__885    source6__885  acer     intel
# ...                      ...   ...       ...
# source2__406    source2__406  acer     intel
# source2__93      source2__93  acer     intel
# source2__110    source2__110  acer       amd
# source2__492    source2__492  acer     intel
# source2__89      source2__89  acer     intel
#
#                                                        cpu_model  cpu_type  \
# instance_id
# source7__1731                                               None        i3
# source7__1655                                               None   celeron
# source1__130   acer aspire e5-571-588m 15.6 laptop with core ...        i5
# source1__112   acer aspire 5742-6838 15.6 notebook with core ...        i5
# source6__885                                            i3-3227u        i3
# ...                                                          ...       ...
# source2__406   n2930. battery information battery chemistry l...   celeron
# source2__93    i5-3230m. battery information battery chemistr...        i5
# source2__110   a4-6210. product name aspire e5-521-435w a4-62...  a-series
# source2__492   i3-3227u. battery information battery chemistr...        i3
# source2__89    2020m 2.40ghz . model brand acer series aspire...   pentium
#
#                                                    cpu_frequency  \
# instance_id
# source7__1731                                           1.90 ghz
# source7__1655                                              1 ghz
# source1__130   acer aspire e5-571-588m 15.6 laptop with core ...
# source1__112   0 mhz. acer aspire 5742-6838 15.6 notebook wit...
# source6__885                                            1.90 ghz
# ...                                                          ...
# source2__406   1.83 ghz. battery information battery chemistr...
# source2__93    2.60 ghz. battery information battery chemistr...
# source2__110   1.80 ghz. product name aspire e5-521-435w a4-6...
# source2__492   1.90 ghz. battery information battery chemistr...
# source2__89    2020m 2.40ghz . model brand acer series aspire...
#
#                ram_capacity  \
# instance_id
# source7__1731             6
# source7__1655             4
# source1__130              4
# source1__112              4
# source6__885              0
# ...                     ...
# source2__406              4
# source2__93               6
# source2__110              4
# source2__492              6
# source2__89               4
#
#                                                         ram_type  \
# instance_id
# source7__1731                                         ddr3 sdram
# source7__1655                                        ddr3l sdram
# source1__130   acer aspire e5-571-588m 15.6 laptop with core ...
# source1__112   acer aspire 5742-6838 15.6 notebook with core ...
# source6__885                              ddr3 sdram. ddr3 sdram
# ...                                                          ...
# source2__406                             ddr3 sdram. ddr3l sdram
# source2__93                               ddr3 sdram. ddr3 sdram
# source2__110                             ddr3 sdram. ddr3l sdram
# source2__492                              ddr3 sdram. ddr3 sdram
# source2__89                                                 None
#
#               ram_frequency  hdd_capacity  ssd_capacity    weight  \
# instance_id
# source7__1731          None           500             0  4.30 lbs
# source7__1655          None           500             0  3.04 lbs
# source1__130           None             0             0      None
# source1__112           None             0             0      None
# source6__885           None           500             0   4.30 lb
# ...                     ...           ...           ...       ...
# source2__406           None           500             0  48.96 oz
# source2__93            None           500             0  112.8 oz
# source2__110           None           500             0      None
# source2__492           None           500             0   68.8 oz
# source2__89            None           500             0      None
#
#                                                       dimensions  \
# instance_id
# source7__1731                                    9.6 in. 13.4 in
# source7__1655                                    8.1 in. 11.4 in
# source1__130                                                None
# source1__112                                                None
# source6__885                                          9.6 . 0.8
# ...                                                          ...
# source2__406   8.3 . 0.9 . battery information battery chemis...
# source2__93    10.8 . 1.4 . battery information battery chemi...
# source2__110   10.1 . 1.2 . 1 . 1.19 . product name aspire e5...
# source2__492   9.6 . 0.8 . battery information battery chemis...
# source2__89    model brand acer series aspire general battery...
#
#                                                            title  \
# instance_id
# source7__1731  acer aspire m5-481t-33226g52mtss 14 led ultrab...
# source7__1655  acer aspire v5-132p-10194g50nss 11.6 touchscre...
# source1__130   acer aspire e5-571-588m 15.6 laptop on sale fo...
# source1__112   acer aspire 5742-6838 15.6 notebook on sale fo...
# source6__885   acer aspire m5-481t-33226g52mtss 14 led ultrab...
# ...                                                          ...
# source2__406   best acer aspire v3-111p-c6lc-intel celeron n2...
# source2__93    best acer aspire e1-771-53236g50mnii-6gb-500gb...
# source2__110   best acer aspire e5-521-435w-amd a-series a4-6...
# source2__492   best acer aspire m5-481t-33226g52mtss-i3-3227u...
# source2__89    best acer aspire e1-731-20204g50mnii-pentium 2...
#
#                                                        new_title  \
# instance_id
# source7__1731  acer aspire m5481t33226g52mtss 14 led ultraboo...
# source7__1655  acer aspire v5132p10194g50nss 11.6 touchscreen...
# source1__130   acer aspire e5571588m 15.6 laptop on sale for ...
# source1__112   acer aspire 57426838 15.6 notebook on sale for...
# source6__885   acer aspire m5481t33226g52mtss 14 led ultraboo...
# ...                                                          ...
# source2__406   best acer aspire v3111pc6lcintel celeron n2930...
# source2__93    best acer aspire e177153236g50mnii6gb500gb hdd...
# source2__110   best acer aspire e5521435wamd aseries a46210 1...
# source2__492   best acer aspire m5481t33226g52mtssi33227u6gb5...
# source2__89    best acer aspire e173120204g50mniipentium 2020...
#
#                                                 new_title_tokens screen_size  \
# instance_id
# source7__1731  [acer, aspire, m5481t33226g52mtss, 14, led, ul...          14
# source7__1655  [acer, aspire, v5132p10194g50nss, 11.6, touchs...        11.6
# source1__130   [acer, aspire, e5571588, m, 15.6, laptop, on, ...        15.6
# source1__112   [acer, aspire, 57426838, 15.6, notebook, on, s...        15.6
# source6__885   [acer, aspire, m5481t33226g52mtss, 14, led, ul...          14
# ...                                                          ...         ...
# source2__406   [best, acer, aspire, v3111pc6lcintel, celeron,...        15.6
# source2__93    [best, acer, aspire, e177153236g50mnii6gb500, ...        15.6
# source2__110   [best, acer, aspire, e5521435wamd, aseries, a4...        15.6
# source2__492   [best, acer, aspire, m5481t33226g52mtssi33227u...        15.6
# source2__89    [best, acer, aspire, e173120204g50mniipentium,...        15.6
#
#                                                 model
# instance_id
# source7__1731               aspire m5481t33226g52mtss
# source7__1655                                  aspire
# source1__130                                   aspire
# source1__112                          aspire 57426838
# source6__885                aspire m5481t33226g52mtss
# ...                                               ...
# source2__406                   aspire v3111pc6lcintel
# source2__93                                    aspire
# source2__110                                   aspire
# source2__492   aspire m5481t33226g52mtssi33227u6gb500
# source2__89                                    aspire
#
# [63 rows x 18 columns]

# %%
acer_title = list(output[0].title)
acer_title
# Out:
# ['acer aspire m5-481t-33226g52mtss 14 led ultrabook - intel core i3 i3-3227u 1.90 ghz 6 gb ram - 500 gb hdd - 20 gb ssd - dvd-writer - intel hd 4000 - windows 7 home premium 64-bit - 1366 x 768 display - bluetooth price comparison at buy.net',
#  'acer aspire v5-132p-10194g50nss 11.6 touchscreen led notebook - intel celeron 1019y 1 ghz - silver 4 gb ram - 500 gb hdd - intel hd graphics - windows 8 64-bit - 1366 x 768 display - bluetooth price comparison at buy.net',
#  'acer aspire e5-571-588m 15.6 laptop on sale for 390.99',
#  'acer aspire 5742-6838 15.6 notebook on sale for 838.43',
#  'acer aspire m5-481t-33226g52mtss 14 led ultrabook - intel core i3 i3-3227u 1.90 ghz - nxm26aa009 - laptops notebooks - acer laptops notebooks - thenerds.net',
#  'acer aspire e1-731-20204g50mnii 17.3 led notebook - intel pentium 2020m 2.40 ghz - nxmgaaa004 - laptops notebooks - acer laptops notebooks - thenerds.net',
#  'acer aspire p3-171-3322y4g12as ultrabook tablet - 11.6 - in-plane switching ips technology - wireless lan - intel core i3 i3-3229y 1.40 ghz - nxm8naa003 - laptops notebooks - acer laptops notebooks - thenerds.net',
#  'acer aspire v5-123-12104g50nrr 11.6 led comfyview notebook - amd e-series e1-2100 1 ghz - red - nxml2aa001 - laptops notebooks - acer laptops notebooks - thenerds.net',
#  'acer aspire e1-532-29574g50mnkk 15.6 led notebook - intel celeron 2957u 1.40 ghz - black - nxmfvaa006 - laptops notebooks - acer laptops notebooks - thenerds.net',
#  'acer aspire v3-772g-747a121.12tbdcckk 17.3 led comfyview notebook - intel core i7 i7-4702mq 2.20 ghz - black - nxm8saa004 - laptops notebooks - acer laptops notebooks - thenerds.net',
#  'acer aspire e1-532-29574g50mnrr 15.6 led notebook - intel celeron 2957u 1.40 ghz - red - nxmhgaa001 - laptops notebooks - acer laptops notebooks - thenerds.net',
#  'acer aspire v5-123-12104g50nkk 11.6 led comfyview notebook - amd e-series e1-2100 1 ghz - black - nxmfqaa005 - laptops notebooks - acer laptops notebooks - thenerds.net',
#  'acer aspire e1-572-34014g50mnkk 15.6 led notebook - intel core i3 i3-4010u 1.70 ghz - black - nxm8eaa007 - laptops notebooks - acer laptops notebooks - thenerds.net',
#  'acer aspire e1-522-45004g50mnkk 15.6 led notebook - amd a-series a4-5000 1.50 ghz - black - nxm81aa025 - laptops notebooks - acer laptops notebooks - thenerds.net',
#  'acer aspire e1-771-33116g50mnii 17.3 led notebook - intel core i3 i3-3110m 2.40 ghz - nxmg7aa006 - laptops notebooks - acer laptops notebooks - thenerds.net',
#  'acer aspire e5-531-c7y7 15.6 led notebook - intel celeron 2957u 1.40 ghz - blue - nxms8aa001 - laptops notebooks - acer laptops notebooks - thenerds.net',
#  'acer aspire v3-111p-43bc 11.6 touchscreen led notebook - intel pentium n3530 2.16 ghz - nxmp0aa001 - laptops notebooks - acer laptops notebooks - thenerds.net',
#  'acer aspire e5-531-c01e 15.6 led notebook - intel celeron 2957u 1.40 ghz - nxmlvaa001 - laptops notebooks - acer laptops notebooks - thenerds.net',
#  'acer aspire v5-573p-54208g1tarr 15.6 touchscreen led notebook - intel core i5 i5-4200u 1.60 ghz - red - nxme3aa001 - laptops notebooks - acer laptops notebooks - thenerds.net',
#  'acer aspire e1-572-54204g50mnrr 15.6 led notebook - intel core i5 i5-4200u 1.60 ghz - red - nxmhfaa001 - laptops notebooks - acer laptops notebooks - thenerds.net',
#  'acer aspire e1-731-10054g50mnii 17.3 led notebook - intel celeron 1005m 1.90 ghz - nxmgaaa003 - laptops notebooks - acer laptops notebooks - thenerds.net',
#  'acer aspire v3-111p-c6lc 11.6 touchscreen led notebook - intel celeron n2930 1.83 ghz - nxmp0aa006 - laptops notebooks - acer laptops notebooks - thenerds.net',
#  'acer aspire v5-573p-54208g1taii 15.6 touchscreen led notebook - intel core i5 i5-4200u 1.60 ghz - nxmbyaa013 - laptops notebooks - acer laptops notebooks - thenerds.net',
#  'acer aspire e1-771-53236g50mnii 17.3 led notebook - intel core i5 i5-3230m 2.60 ghz - nxmg7aa005 - laptops notebooks - acer laptops notebooks - thenerds.net',
#  'acer aspire v5-132p-10194g50nss 11.6 touchscreen led notebook - intel celeron 1019y 1 ghz - silver - nxmdraa001 - laptops notebooks - acer laptops notebooks - thenerds.net',
#  'acer aspire e5-521-435w 15.6 led notebook - amd a-series a4-6210 1.80 ghz - black - nxmlfaa010 - laptops notebooks - acer laptops notebooks - thenerds.net',
#  'acer aspire m5-481pt-53336g52mass 14 touchscreen led ultrabook - intel core i5 i5-3337u 1.80 ghz - nxm3waa007 - laptops notebooks - acer laptops notebooks - thenerds.net',
#  'acer aspire e1-572-34014g50mnrr 15.6 led notebook - intel core i3 i3-4010u 1.70 ghz - red - nxmhfaa002 - laptops notebooks - acer laptops notebooks - thenerds.net',
#  ' brand new acer consumer acer aspire p3-171-3322y4g12as ultrabook tablet - 11.6 - in-plane switching ips technology - wireless lan - intel core i3 i3-3229y 1.40 ghz computers accessories',
#  'miniprice.ca - acer aspire s7-392-54218g25tws 13.3 touchscreen led ultrabook - intel core i5 i5-4210u 1.70 ghz - 8 gb ram - 256 gb ssd - intel - windows 8.1 64-bit - 2560 x 1440 display - bluetooth nx.mbkaa.032 ',
#  ' acer aspire v5-122p-0857 12-inch touchscreen laptop 1 ghz a4-1250 a-series processor, 4gb ram, 500gb hard drive chill silver laptop computers computers accessories',
#  ' acer aspire s7-392-5401 13.3-inch wqhd touchscreen ultrabook crystal white computers accessories',
#  ' acer aspire e5-571-588m 15.6 notebook computer, intel core i5-4210u 1.7ghz, 4gb ram, 500gb hdd, windows 8.1, midnight black computers accessories',
#  ' acer aspire r7-572-6423 2-in-1 15.6-inch touch-screen laptop - intel coretm i5-4200u processor 8gb memory 1tb hard drive windows 8.1 silver computers accessories',
#  'acer aspire 17.3 laptop, e1-731-20204g50 - walmart.com',
#  'acer aspire laptop pc, e1-771-53236g50mnii - walmart.com',
#  'acer silver aspire m5-481t-33226g52mtss 14 laptop pc - walmart.com',
#  'acer aspire laptop pc, e1-532-29574g50mnrr - walmart.com',
#  'acer refurbished laptop, v5-122p-0408 - walmart.com',
#  'acer aspire laptop pc, e1-771-33116g50mnii - walmart.com',
#  'acer glossy black 11.6 aspire v5-123-3466 laptop pc with amd e1-2100 dual-core processor, 4gb memory, 500gb hard drive and windows 8 computers walmart.com',
#  'acer aspire e1 522 5423 15 6 amd a4 5000 4gb 500gb nx m81aa 025 notebook new ebay',
#  'acer extensa ex5620 4025 15 4 120 gb intel t8300 core2duo 2 4 ghz 2gb ram ebay',
#  'acer aspire e1 531 2438 15 6 notebook dark grey 500gb 4gb 887899084560 ebay',
#  'acer aspire as5552 7474 15 6 320 gb amd phenom ii quad core 2 2 ghz 4 886541154361 ebay',
#  'acer aspire as5552 7819 notebook amd phenom ii dual core n660 3 0ghz 4gb ebay',
#  'acer glossy black 11.6 aspire v5-123-3466 laptop pc with amd e1-2100 dual-core',
#  'acer aspire e1 531 2438 15 6 notebook dark grey 500gb 4gb 887899084560 ebay',
#  'acer extensa 5620 5635 6897 15 4 core 2 duo 2 10ghz 3gb 120gb notebook ebay',
#  'acer aspire 5742 6838 15 6 intel core i5 2 53ghz 4gb ram 250gb hd win7 webcam ebay',
#  'other laptops notebooks - acer aspire r7-572-54208g1tass - 15.6 nx.m94ea.002 for sale in johannesburg id 158050553 ',
#  'best acer aspire m5-481pt-53336g52mass-6gb-500gb hdd-20 gb ssd win 8-14 touchscreen led ultrabook topendelectronics uk',
#  'best acer aspire e1-771-33116g50mnii-i3-3110m-6gb-500gb hdd-win 7-17.3 led notebook topendelectronics uk',
#  'best acer aspire v5-573p-54208g1tarr-i5-4200u-8gb-1 tb hdd-win 8.1-15.6 touchscreen led notebook-red topendelectronics uk',
#  'best acer aspire v5-132p-10194g50nss-celeron 1019y-4gb-500gb hdd-win 8-11.6 touchscreen led notebook topendelectronics uk',
#  'best acer aspire v5-573p-54208g1taii-i5-4200u-8gb-1 tb hdd-win 8.1-15.6 touchscreen led notebook topendelectronics uk',
#  'best acer aspire v5-123-12104g50nkk-e-series e1-2100-4gb-500gb hdd-win 8-11.6 led notebook-red topendelectronics uk',
#  'best acer aspire v5-123-12104g50nkk-e-series e1-2100-4gb-500gb hdd-win 8-11.6 led notebook-black topendelectronics uk',
#  'best acer aspire v3-111p-c6lc-intel celeron n2930-4gb-500gb hdd-win 8.1-11.6 touchscreen led notebook topendelectronics uk',
#  'best acer aspire e1-771-53236g50mnii-6gb-500gb hdd-win 7-17.3 led notebook topendelectronics uk',
#  'best acer aspire e5-521-435w-amd a-series a4-6210 1.80ghz-4gb -500gb hdd-win 8.1 64-bit-15.6 led notebook -black topendelectronics uk',
#  'best acer aspire m5-481t-33226g52mtss-i3-3227u-6gb-500gb hdd 20 gb ssd-win 7-14 led ultrabook topendelectronics uk',
#  'best acer aspire e1-731-20204g50mnii-pentium 2020m-4gb-500gb hdd-win 7-17.3 led notebook topendelectronics uk']

# %%
regex = [r'\s[esrvmpa]\d-?\s?.....-?....?', r'\s[esrvma]?\d-....', r'\s?acer\saspire\s\d{4}-\d{4}', r'\s?acer\sextensa\s.{0,2}\d{4}\s?\d{0,4}', r'\s?acer\saspire\sas\d{4}-?\s?\d{4}',
        r'\s?acer\saspire\s\d{4}-?\s\d{4}']
c = 0
for t in acer_title:
    found = False
    for r in regex: 
        cr = re.compile(r)
        if re.search(cr, t):
#             print(re.search(cr, t).group())
            c+=1
            found = True
            break
    if not found:
        print(t)  
        pass
print(c)
# Out:
# 63

# %%
asus_title = list(output[1].title)
asus_title
# Out:
# ['asus zenbook ux301la-dh51t 13.3 touchscreen ultrabook - intel core i5 i5-4200u 1.60 ghz - blue 8 gb ram - 256 gb ssd - intel hd 4400 - windows 8 64-bit - 2560 x 1440 display - bluetooth price comparison at buy.net',
#  'asus ux31a-xb52 13.3 laptop on sale for 1414.95',
#  'asus zenbook prime ux31a 13.3 ultrabook on sale for 749.99',
#  'asus zenbook ux21e 11 6 core i5 2467m 128gb ssd 4gb ram microsoft office inclu ebay',
#  'new asus zenbook prime ux31a xb52 13 3 fhd ultrabook i5 3317u 4gb 256gb ssd 886227257386 ebay',
#  'open box asus zenbook ux21e dh52 i5 2467m 1 60ghz 4gb 128gb ssd 11 6 win 7 884840974178 ebay',
#  'best asus zenbook prime ux31a-xb52-core i5-3317u 1.70 ghz-4gb ram-256gb ssd-win 7 pro-13.3 ultrabook-silver aluminum topendelectronics uk',
#  'best asus zenbook ux301la-dh51t intel core i5-4200u-1.6ghz-13.3 touchscreen ultrabook topendelectronics uk']

# %%
c = 0
regex = [r'\sux...-.....', r'\sux.{3,5}-?.....?'] # There is a problem here
c = 0
for t in asus_title:
    found = False
    for r in regex: 
        cr = re.compile(r)
        if re.search(cr, t):
#             print(re.search(cr, t).group())
            c+=1
            found = True
            break
    if not found:
        print(t)  
        pass
print(c)
# Out:
# 8

# %%
dell = ((list(output[2].title)))
print(len(dell))
dell
# Out:
# 11
# ['dell silver 15.6 inspiron 15 5547 laptop pc with intel core i5-4210u processor, 6gb memory, touchscreen, 1tb hard drive and windows 8.1 computers walmart.com',
#  'dell inspiron 15 7537 15 6 touch screen laptop i7 4500u 1 8ghz 8gb 1tb 1080p bt ebay',
#  'dell inspiron 17r i5735 17 3 hd a8 5545m 1 7ghz 8gb ram 1tb hdd win 8 1 laptop ebay',
#  'dell inspiron 15 7000 7537 i7 4500u 8gb 1tb 1080p touch bklit bt dell wty ebay',
#  'brand new dell inspiron 15 7000 7537 i7 4500u 8gb 1tb 1080p webcam backlit bt w8 ebay',
#  'dell inspiron 17r 5735 laptop quad core a8 5545m 1tb 8gb ddr3 windows 8 1 ebay',
#  'dell inspiron 15 5547 core i5 4th gen 6gb 1tb win 8 64 bit ebay',
#  'dell inspiron 15 7537 8gb intel r core tm i7 4500u cpu 1 80ghz windows 8 ebay',
#  'dell inspiron 15 7000 7537 i7 4500u 8gb 1tb hybrid 1080p touch gt750m wcam w8 ebay',
#  'dell inspiron 17 3 win8 1 m731r amd quad core a8 5545m 1 7ghz 8gb 1tb laptop ebay',
#  'dell inspiron 15 i5547-3751slv 15.6 i5547-3751slv b h']

# %%
c = 0
regex = [r'\s[nmi]\d{3,4}(-\d{4})?', r'\sinspiron\s15?\s?\d{4}', r'\sinspiron\s17?.?\s?\d{4}']
words = ['inspiron', '15', '17', '   ', '  ']
for t in dell:
    found = False
    for r in regex: 
        cr = re.compile(r)
        if re.search(cr, t):
#             print(re.search(cr, t).group())
            c+=1
            found = True
            break
    if not found:
        print(t)    
print()
print(c)
# Out:
# 11

# %%
lenovo = (list(output[4].title))
print(len(lenovo))
# lenovo
# Out:
# 56

# %%
c = 0
regex = [r'\sx\d{3}\s?tablet?\s?\d{0,4}', r'\sx\d{3}\s?laptop?\s?\d{0,4}', r'\sx\d{3}\s?\d{0,4}',r'\sx\d{1}\scarbon\s\d{4}', r'\sx\d{1}\scarbon touch\s\d{4}']
for t in lenovo:
    found = False
    for r in regex: 
        cr = re.compile(r)
        if re.search(cr, t):
#             print(re.search(cr, t).group(), "___", t[:50])
            c+=1
            found = True
            break
    if not found:
        print(t)
    
print()
print(c)
# Out:
# miniprice.ca - lenovo thinkpad 3448c5u 14 led ultrabook - intel core i7 i7-3667u 2 ghz - black - 1600 x 900 hd display - 8 gb ram - 128 gb ssd - intel hd 4000 graphics - bluetooth - webcam - finger print reader 3448c5u
# lenovo thinkpad x1 carbon touch ultrabook i7 3667u 8gb ram 240gb ssd 3444cuu 887619432923 ebay
# lenovo thinkpad x1 carbon ultrabook i7 3667u 2ghz 14 8gb 240gb ssd 3448 2d9 02 ebay
# lenovo thinkpad x1 carbon ultrabook i7 3667u 2ghz 14 8gb 240gb ssd 3448 2d9 ebay
#
# 52

# %%
hp = ((list(output[3].title)))
list(output[3].title)
# Out:
# ['hp elitebook 8560p intel core i7 quad 2.2ghz 128gb ssd 15.6-inch laptop computer refurbished overstock.com shopping - the best deals on laptops',
#  'hp 8540w notebook pc refurbished overstock.com shopping - the best deals on laptops',
#  'hp elitebook 8560p intel core i7 quad core 2.2ghz 750gb 15.6-inch laptop computer refurbished overstock.com shopping - the best deals on laptops',
#  'hp hewlett-packard elitebook 8440p 14 notebook 2.6 ghz intel core i7-620m, 4 gb ddr3, 250 gb hdd, dvdrw, windows 7 professional, led backlight professional - 700443660570 price comparison at buy.net',
#  'hp elitebook revolve 810 g2 tablet - 11.6 - core i5 4310u - windows 8.1 pro 64-bit - 4 gb ram - 128 gb ssd',
#  'hp 15-f009wm 15.6 notebook pc on sale for 229.22',
#  'hp 15-g070nr 15.6 laptop on sale for 229.00',
#  'hp elitebook revolve 810 g2 tablet pc - 11.6 - wireless lan - intel core i5 i5-4310u 2 ghz - j8u39utaba - laptops notebooks - hewlett-packard laptops notebooks - thenerds.net',
#  ' hp 15-r150nr 15.6-inch laptop core i3-4005u, 4gb ram, 750gb hd, windows 8.1 computers accessories',
#  ' hp 15-d090nr 15.6 laptop windows 7 computers accessories',
#  ' hp elitebook revolve 810 d3k52ut 11.6 led ultrabook intel core i3-3227u 1.9ghz 4gb ddr3 128gb ssd windows 7 professional laptop computers computers accessories',
#  'refurbished hp 8540w 15.5 , 320gb hard drive, 4gb memory, intel core i7, win 7 pro staples',
#  'refurbished hp 8540w 15.5 , 320gb hard drive, 4gb memory, intel core i7, win 7 pro staples',
#  ' hp elitebook 8770w c6y84ut 17-inch notebook 2.4 ghz intel core i7-3630qm processor, 3gb ddr3, 320gb hdd, windows 7 professional gunmetal laptop computers computers accessories',
#  'hp 15.6 laptop pc 15 f009wm - walmart.com',
#  'hp elitebook 8770w c6y84ut 17-inch notebook 2.4 ghz intel core i7-3630qm processor, 3gb ddr3, 320gb hdd, windows 7 professional gunmetal comprar en nicaragua',
#  'hp 15-g012dx 15.6 laptop pc - amd quad-core a8 4gb memory 750gb hd dvdrw cd-rw hd webcam windows 8.1 64-bit black licorice comprar en nicaragua',
#  'hp 15-g070nr 15.6-inch laptop optical drive not included comprar en nicaragua',
#  'hp elitebook 8440p notebook 14 intel core i7 620m 2 66ghz 8g 500g win 7 pro ebay',
#  'hp ultrabook folio 9470m vpro core i5 3427u 1 8ghz 8gb 500gb win7 webcam laptop ebay',
#  'hp 8460p elitebook core i5 2520m 2 5ghz 6gb 500gb webcam win 7 aluminium laptop ebay',
#  'hp elitebook 8540w core i7 2 8ghz 4gb 320gb gaming laptop w win 7 install cd ebay',
#  'hp elitebook 8440p notebook 14 intel core i7 620m 2 66 4g 120g ssd win7 pro ebay',
#  'hp elitebook 8540w core i7 2 67ghz 8gb 320gb gaming laptop w win 7 install cd ebay',
#  'hp elitebook 8460p 14 laptop intel core i5 2520m 2 5ghz 2gb ram 320gb hd wifi ebay',
#  'hp elitebook 8540w core i7 2 67ghz 4gb 320gb webcam win 7 nvidia gaming laptop ebay',
#  'hp elitebook 8440p ql113us core i7 2 67ghz 300gb 4gb win 7pro office std ebay',
#  'hp elitebook 8540w 15 notebook intel core i7 8gb ram 1 6ghz dedicated gpu 720qm ebay',
#  'hp elitebook 8540w core i7 2 67ghz 6gb 320gb webcam win 7 nvidia gaming laptop ebay',
#  'hp elitebook 8740w 17 laptop intel core i7 m640 2 8ghz 4gb ram 320gb hd ebay',
#  'hp elitebook 2560p 12 5 intel core i5 2540m 2 60ghz 8gb ram 250gb hd win7pro ebay',
#  'hp 8460p elitebook core i5 2520m 2 5ghz 6gb 500gb webcam win 7 aluminium laptop ebay',
#  'hp elitebook folio 9470m notebook i5 3427u 1 8ghz 8gb ram 180gb ssd 14 win7 pro ebay',
#  'hp 15 f009wm laptop for sale ebay',
#  'hp elitebook 8540w core i7 2 67ghz 8gb 320gb webcam win 7 nvidia gaming laptop ebay',
#  'hp elitebook 8540w core i7 2 67ghz 8gb 320gb gaming laptop w win 7 install cd ebay',
#  'hp elitebook 8570p 15 6 500gb intel core i7 3540m 3 00ghz 8gb win8 uln 887758502327 ebay',
#  'hp 8460p 14 led laptop intel i5 2520m 250gb qr251us aba 64 bit wp7 80002160 886111688975 ebay',
#  'hp 8730w t9550 2 66 4g 1tb 17 dvrw win 7 pro webcam wifi nh451uc aba ebay',
#  'hp elitebook 8440p notebook 14 intel core i7 620m 2 66ghz 4g new 500g win 7 pro ebay',
#  'hp elitebook 8530p core 2 duo t9400 2 53ghz 4gb 320 15 4 no os 2353 ebay',
#  'hp8530w 15 4 4gb elitebook and intel core 2 duo t9400 2 53 ghz 250gb hd ebay',
#  'hp elitebook 8540w core i7 2 67ghz 8gb 320gb webcam win 7 nvidia gaming laptop ebay',
#  'hp elitebook 9470m core i5 3427u 1 8ghz 4gb 180gb w7pro64 14in laptop uln ebay',
#  'hp elitebook 8540w core i7 2 67ghz 8gb 320gb gaming laptop w win 7 install cd ebay',
#  'hp elitebook 8440p laptop core i7 2 80ghz 8gb 320gb dvdrw windows 7 pro webcam ebay',
#  'hp elitebook 8540w core i7 620m 2 67 laptop 320gb 4gb win 7 notebook webcam ebay',
#  'hp elitebook 8540w core i7 2 67ghz 8gb 320gb gaming laptop w win 7 install cd ebay',
#  'hp 8460p elitebook core i5 2520m 2 5ghz 4gb 500gb webcam win 7 aluminium laptop ebay',
#  'win7 hp 12 034 2540p core i7 640 2 13ghz 3gb 80gb dvd batt laptop 6monthwty ebay',
#  'hp elitebook 8440p core i7 620m 2 67 laptop 128gb ssd 4gb win7 notebook webcam ebay',
#  'hp elitebook 8460p laptop webcam i5 2 5ghz 4gb 320gb win 7 pro notebook pc dvdrw 886111688975 ebay',
#  'hp 8460p elitebook core i5 2520m 2 5ghz 6gb 500gb webcam win 7 aluminium laptop ebay',
#  'laptop hp elitebook 8460p intel i5 2520m 2 50ghz 4gb ram 250gb hdd webcam ebay',
#  'hp elitebook 8540w core i7 2 67ghz 8gb 320gb gaming laptop w win 7 install cd ebay',
#  'hp 8460p elitebook core i5 2520m 2 5ghz 6gb 500gb webcam win 7 aluminium laptop ebay',
#  'hp 8460p elitebook core i5 2520m 2 5ghz 6gb 500gb webcam win 7 aluminium laptop ebay',
#  'hp compaq nc6400 14 1 lcd core duo 1 8ghz 80 gb hd 1gb ram dvd cdrw win xp wifi ebay',
#  'hp elitebook 8530p core 2 duo t9400 2 53ghz 4gb 320 15 4 034 no os 2392 ebay',
#  'hp elitebook revolve 810 g2 tablet 11 6 i5 4200u 1 6ghz 4gb ram 128gb ssd touch ebay',
#  'hp elitebook 6930p c2d t9600 2 8ghz 4gb 320gb webcam bluetooth wifi laptop ebay',
#  'hp elitebook 8730w 17 webcam core2duo t9550 2 66ghz 4gb 320gb win7 nvidia laptop ebay',
#  'hp compaq nc6400 core 2 duo t5500 1 66ghz 1gb 80gb fingerprint read zorin ebay',
#  'hp 8460p elitebook core i5 2520m 2 5ghz 4gb 500gb webcam win 7 aluminium laptop ebay',
#  'hp elitebook 8540w 15 6 1920x1080 core i7 2 6ghz 4gb 320gb nvidia gaming laptop ebay',
#  'hp elitebook 8540w core i7 620m 2 67 laptop 128gb ssd 8gb win 7 notebook webcam ebay',
#  'hp elitebook 8460p i7 2 7ghz 4gb 320gb with win 7 pro warranty until sept 2014 ebay',
#  'hp compaq 6930p laptop 14 lcd intel c2d p8700 2 53 4gb new 120g ssd win 7 pro ebay',
#  'hp 8460p elitebook core i5 2520m 2 5ghz 4gb 500gb webcam win 7 aluminium laptop ebay',
#  'hp compaq nc6400 80gb hd 1gb ram 1 83ghz core 2 duo xp office wifi ebay',
#  'hp pavilion g4 1016dx windows 8 1 dualcore cpu 320gb hdd 4gb ram ebay',
#  'hp c6z03ut aba 8470w 14 elitebook mobile workstation i7 3630qm 2 4gz 8gb 500gb 887111587435 ebay',
#  'hp elitebook 2170p i5 3427u 1 80ghz 4gb ram 320gb hd win7 64b ebay',
#  'hp elitebook 8540w core i7 2 67ghz 6gb 320gb webcam win 7 nvidia gaming laptop ebay',
#  'hp elitebook 8540w core i7 620m 2 67 laptop notebook 750gb 8gb windows 7 webcam ebay',
#  'hp elitebook 8530p core 2 duo t9400 2 53ghz 4gb 320 15 4 no os 2352 ebay',
#  'hp elitebook 8530w 15 4 core 2 duo t9400 2 53ghz 4gb 250gb nvidia gaming laptop ebay',
#  'hp elitebook 8540w core i7 2 67ghz 8gb 320gb webcam win 7 nvidia gaming laptop ebay',
#  'hp elitebook 8540w core i7 2 67ghz 8gb 320gb webcam win 7 nvidia gaming laptop ebay',
#  'hp compaq nc6400 14 1 intel core 2 duo 1 83 ghz notebook 882780557260 ebay',
#  'hp elitebook 8460p core i5 2450m 14 4gb mem 1tbhd 64bit windows 8 pro free ship ebay',
#  'hp elitebook 8440p 14 i7 2 8ghz 4gb ram 320gb hdd windows 7 pro 886111067978 ebay',
#  'hp elitebook 8540w core i7 2 67ghz 8gb 320gb gaming laptop w win 7 install cd ebay',
#  'hp compaq 6930p laptop 14 lcd intel c2d p8700 2 53 4gb new 240g ssd win 7 pro ebay',
#  'hp compaq 6930p laptop 14 lcd intel c2d p8700 2 53 4gb 500g dvd rw win 7 pro ebay',
#  'hp 8460p elitebook core i5 2520m 2 5ghz 4gb 500gb webcam win 7 aluminium laptop ebay',
#  'hp elitebook 8540w intel core i7 q820 1 73ghz 4gb 1tb nvidia windows 7 office ebay',
#  'hp 8460p elitebook core i5 2520m 2 5ghz 4gb 500gb webcam win 7 aluminium laptop ebay',
#  'brand new hp 15 g070nr 15 6 4gb 500gb hd windows 8 1 hdmi no tax ebay',
#  'hp elitebook 6930p t9600 2 8ghz 4gb 320gb webcm blutooth wifi laptop ebay',
#  'hp 15 series laptop brand new 500 gb ebay',
#  'hp compaq nc6400 core 2 duo laptop 2 00ghz 1gb fully tested working ebay',
#  'hp compaq nc6400 14 1 60 gb intel core duo 1 80 ghz 1 5 memory win7 pro ebay',
#  'hp 15 p030nr special edition beats laptop 15 6 inch touchscreen 8gb ram 1tb ebay',
#  'hp 15 g070nr 15 6 inch wled 4gb ram 500gb win8 1 laptop brand new sealed ebay',
#  'new hp 15 f009wm laptop amd dual core processor e1 2100 1 0ghz 4g 500 gb win 8 1 ebay',
#  'hp 8460p elitebook core i5 2520m 2 5ghz 4gb 500gb webcam win 7 aluminium laptop ebay',
#  'hp elitebook 8530w 15 4 core 2 duo t9400 2 53ghz 4gb 250gb nvidia gaming laptop ebay',
#  'hp elitebook 8460p intel core i5 2 5ghz 4gb 500gb win 7 pro 14 laptop ebay',
#  'new hp 15 g070nr 15 6 4gb ddr3 500gb hd webcam hdmi windows 8 1 laptop notebook ebay',
#  'hp 8540w 15 6 core i7 2 67ghz 8gb 500gb nvidia fx880m 1gb ebay',
#  'hp elitebook 8440p laptop core i7 2 80ghz 8gb 320gb dvd rw windows 7 pro webcam ebay',
#  'hp elitebook 8540w core i7 2 67ghz 4gb 320gb webcam win 7 nvidia gaming laptop ebay',
#  'hp compaq 6930p laptop 14 lcd intel c2d p8600 2 4ghz 4gb 500g dvdrw win 7 pro ebay',
#  'hp elitebook 8540w core i7 2 67ghz 8gb 320gb webcam win 7 nvidia gaming laptop ebay',
#  'hp elitebook 8540w 15 6 laptop notebook pc 2 6ghz i7 500hdd 8gbram nvidia 880m ebay',
#  'laptop hp elitebook 8460p intel i5 2520m 2 50ghz 4gb ram 120gb hdd bluetooth ebay',
#  'hp ultrabook folio 9470m vpro core i5 3427u 1 8ghz 8gb 500gb win7 webcam laptop ebay',
#  'hp elitebook 8540w core i7 2 67ghz 4gb 320gb webcam win 7 nvidia gaming laptop ebay',
#  'hp elitebook 8540w core i7 2 67ghz 4gb 320gb webcam win 7 nvidia gaming laptop ebay',
#  'hp pavilion g4 1229dx notebook pc 886112414542 ebay',
#  'd7p60aw aba hp elitebook revolve 810 intel i5 3437u 1 9ghz 256gb ssd 4gb 11 6 w7 ebay',
#  'hp elitebook 8540w core i7 2 67ghz 6gb 320gb webcam win 7 nvidia gaming laptop ebay',
#  'hp 8460p elitebook core i5 2520m 2 5ghz 6gb 500gb webcam win 7 aluminium laptop ebay',
#  'hp elitebook 8540w core i7 620m 2 67 laptop 1tb 8gb win 7 notebook 1920 x 1080 ebay',
#  'hp elitebook 8540w core i7 2 67ghz 4gb 320gb gaming laptop w win 7 install cd ebay',
#  'hp 12 2540p win7 core i7 640 2 13ghz 3gb 250gb batt laptop 6monthwty ebay',
#  'hp elitebook 8440p intel core i7 2 67 ghz 320 gb 4 gb win 7 professional 14 1 ebay',
#  'hp elitebook 8540w 15 6 notebook intel core i7 1 6ghz ebay',
#  'new hp elitebook revolve 810 g1 d3k52ut 11 6 touchscr laptop i3 3227u 4gb 128gb 887758326275 ebay',
#  'hp elitebook 8540w 15 6 1920x1080 core i7 2 6ghz 4gb 320gb nvidia gaming laptop ebay',
#  'hp elitebook 8440p laptop core i7 2 8ghz 4gb 320gb dvdrw windows 7 pro webcam ebay',
#  'hp elitebook 8740w quad core i7 1 6 q720 laptop 750gb 8gb win 7 notebook office ebay',
#  'hp elitebook 8460p 14 250gb intel core i5 2 5 ghz 8 gb notebook 886111511143 ebay',
#  'spanish hp 2570p 12 5 notebook i5 3210m 4gb 500gb win7 bt espanol 887111811257 ebay',
#  'hp compaq nc6400 14 1 notebook parts or repair ebay',
#  'hp elitebook 8440p laptop 14 led intel core i7 4gb ddr3 200gb ssd win 7 pro ebay',
#  'hp elitebook 8740w bw231us 17 laptop i5 520m 2 4ghz 4gb 320gb dvdrw win 7 pro ebay',
#  'hp elitebook 8540w core i7 2 67ghz 6gb 320gb webcam win 7 nvidia gaming laptop ebay',
#  'hp compaq nc6400 14 laptop notebook intel core 2 duo 2 00ghz 1gb ddr2 d combo 616983297414 ebay',
#  'hp elitebook 2170p intel core i5 3427u 1 8ghz 4gb 128gb ssd win7pro 11 6 uvg ebay',
#  'hp elitebook 2170p i5 3427u 1 80ghz 4gb ram 320gb hd win7 64b ebay',
#  'hp ultrabook folio 9470m vpro core i5 3427u 1 8ghz 8gb 500gb win7 webcam laptop ebay',
#  'hp elitebook 8540w intel core i7 q820 1 73ghz 4gb 1tb nvidia windows 7 office ebay',
#  'brand new sealed hp 15 f009wm notebook amd dual core e1 2100 1 0ghz 4g 500gb ebay',
#  'hp elitebook 8540w 15 6 1920x1080 core i7 2 6ghz 4gb 320gb nvidia gaming laptop ebay',
#  'gaming laptop windows 7 1920x1080 hp core i7 620m 2 7ghz 4gb 8540w 15 6monthwty ebay',
#  'hp 8460p elitebook core i5 2520m 2 5ghz 4gb 500gb webcam win 7 aluminium laptop ebay',
#  'hp elitebook 8540w 15 6 1920x1080 core i7 2 6ghz 4gb 320gb nvidia gaming laptop ebay',
#  'hp elitebook 8740w energy star laptop pc i7 vpro 8gb ram 250gb hdd nvidia 2800m ebay',
#  'hp elitebook 8540w core i7 2 67ghz 8gb 320gb gaming laptop w win 7 install cd ebay',
#  'hp elitebook 8460p i5 2 5ghz 4gb 320gb dvdrw webcam fpr onsite warranty 11 2014 886111585465 ebay',
#  'hp elitebook 8740w 17 wxga laptop core i5 m520 2 40ghz 4gb ram 320gb hdd ebay',
#  'hp elitebook 8560p intel i5 2520m 2 50ghz 8gb ram 500gb hdd windows 7 pro ebay',
#  'hp elitebook 8440p intel core i7 620m 2 66hz 8gb ram ebay',
#  'hp 8460p elitebook core i5 2520m 2 5ghz 6gb 500gb webcam win 7 aluminium laptop ebay',
#  'hp elitebook 8440p core i7 620m 2 67 laptop 320gb 4gb win 7 notebook webcam ebay',
#  'hp elitebook 8460p i5 2 5ghz 4gb ram 14 128 ssd windows 7 qs719us aba grade a ebay',
#  'hp elitebook 8540w intel core i7 720qm quad core 1 6ghz 4gb 250gb dvd rw win7 ebay',
#  'hp elitebook 2760p 12 1 led tablet pc core i5 i5 2540m 2 6ghz laptop 886111677245 ebay',
#  'hp 8460p elitebook core i5 2520m 2 5ghz 6gb 500gb webcam win 7 aluminium laptop ebay',
#  'hp elitebook 8540w core i7 2 67ghz 4gb 320gb gaming laptop w win 7 install cd ebay',
#  'hp elitebook 8540w intel core i7 640m 2 80ghz 4gb 320gb wi fi bt webcam xt904ut ebay',
#  'hp elitebook 8440p 2 67ghz intel core i7 4gb ram 160gb fingerprint ebay',
#  'gaming laptop windows 7 hp core i7 2620m 2 7ghz 4gb 8560p 15 6 6month warranty ebay',
#  'hp pavilion dv6000 dv6700 webcam amd turion 64x2 2 0ghz 3gb laptop notebook ebay',
#  'hp compaq 6930p laptop 14 lcd intel c2d p8600 2 4ghz 4gb 160g dvd rw win 7 pro ebay',
#  'hp elitebook 8540w core i7 2 67ghz 8gb 320gb webcam win 7 nvidia gaming laptop ebay',
#  'hp 8460p elitebook core i5 2520m 2 5ghz 4gb 500gb webcam win 7 aluminium laptop ebay',
#  'hp compaq 6930p laptop 14 lcd intel c2d p8600 2 4ghz 4gb 80g dvd rw win 7 pro ebay',
#  'hp elitebook 8740w 17 laptop intel core i7 m640 2 8ghz 4gb ram no hdd ebay',
#  'hp elitebook 8560p core i5 2 6ghz 8gb ram 500gb drive dvdrw win7 pro 64bit ebay',
#  'hp elitebook 8540w core i7 2 67ghz 4gb 320gb webcam win 7 nvidia gaming laptop ebay',
#  'hp elitebook 8540w core i7 2 67ghz 4gb 320gb webcam win 7 nvidia gaming laptop ebay',
#  'hp elitebook 8540w core i7 620m 2 67 laptop 640gb 8gb win 7 notebook webcam ebay',
#  'hp elitebook 8540w core i7 2 8ghz 4gb 320gb gaming laptop w win 7 install cd ebay',
#  'hp elitebook 8540w core i7 620m 2 67 laptop 320gb 4gb win 7 notebook ebay',
#  'hp elitebook 8540w core i7 2 67ghz 8gb 320gb webcam win 7 nvidia gaming laptop ebay',
#  'new open box hp 15 g012dx 4gb 750gb hd 15 6 windows 8 1 quad core dvdrw hdmi ebay',
#  'new hp 15 6 laptop 500gb hdd 4gb memory dual core windows 8 hdmi webcam wifi ebay',
#  'hp elitebook 8440p laptop notebook i7 2 67ghz 4gb 250gb win 7 dvdrw wifi nvidia ebay',
#  'hp elitebook 8540w core i7 2 8ghz 4gb 320gb gaming laptop w win 7 install cd ebay',
#  'hp elitebook 8540w core i7 2 67ghz 4gb 320gb webcam win 7 nvidia gaming laptop ebay',
#  'hp ultrabook folio 9470m vpro core i5 3427u 1 8ghz 8gb 500gb win7 webcam laptop ebay',
#  'hp 8460p elitebook core i5 2520m 2 5ghz 6gb 500gb webcam win 7 aluminium laptop ebay',
#  'hp elitebook 8540w core i7 2 67ghz 4gb 320gb gaming laptop w win 7 install cd ebay',
#  'hp elitebook 8540w 8gb ram 320gb hdd 2 67ghz i7 cpu great condition ebay',
#  'hp 8460p elitebook core i5 2520m 2 5ghz 6gb 500gb webcam win 7 aluminium laptop ebay',
#  'hp pavilion dv6000 dv6700 amd athlon 64x2 1 7ghz 3 0gb wifi laptop notebook 2055 ebay',
#  'hp elitebook 8440p notebook 14 intel core i7 620m 2 66ghz 4g 250g win 7 pro ebay',
#  'hp 8460p elitebook core i5 2520m 2 5ghz 4gb 500gb webcam win 7 aluminium laptop ebay',
#  'hp elitebook 8540w core i7 620m 2 67 laptop 128gb ssd 8gb win 7 notebook ebay',
#  'hp elitebook 8540w core i7 2 67ghz 6gb 320gb webcam win 7 nvidia gaming laptop ebay',
#  'hp elitebook 8740w bw231us 17 laptop i5 520m 2 4ghz 4gb 320gb dvdrw win 7 pro ebay',
#  'hp elitebook 2560p 12 5 034 intel core i5 2540m 2 60 ghz 8 gb memory 128 gb ssd hd ebay',
#  'other laptops notebooks - hp elitebook revolve 810 f1n29ea for sale in johannesburg id 158360141 ',
#  'other laptops notebooks - hp elitebook folio 9470m c3c98es was listed for r24,958.80 on 26 oct at 01 03 by firstshop in johannesburg id 164474473 ',
#  'best hp elitebook 8470w-c7a68ut-i7-3630qm-8gb-500gb hdd-win 7-14 led notebook topendelectronics uk',
#  'best hp elitebook 8470w-c6z03ut-i7-3630qm-8gb-128gb ssd-win 7-14 led notebook topendelectronics uk',
#  'best hp elitebook-2570p-d8e76ut-i5-3340m-4gb-500gb-hdd-win 7-12.5 led notebook topendelectronics uk',
#  'best hp elitebook-2570p-d8e77ut-i5-3340m-4gb-180gb-win 7-12.5 led notebook topendelectronics uk',
#  'hp 15-r150nr 15.6 touchsmart notebook computer j9k39ua aba',
#  ' 239 hp 15-g070nr, hp 15-g070nr notebook pc',
#  ' 499 hp 15-d090nr, hp 15-d090nr notebook pc',
#  'hp lj540ut elitebook 8460p 14 notebook - vology',
#  'hp b5p99ut elitebook 8570p 15.6 notebook - vology',
#  'hp c6z62ut elitebook folio 9470m 14 ultrabook - vology',
#  'hp lq164aw elitebook 8460p 14 notebook - vology',
#  'hp c6z49ut elitebook 2570p 12.5 notebook - vology']

# %%
c = 0
regex = [r'\sfolio\s?\d{4}.', r'\selitebook\s?-?\d{3,4}.',
         r'\s\d{2}-.{4,6}', r'hp\s?\d{4}.', r'\spavilion\s?..\s?.{5}',
         r'\s?compaq\s?.{5}', r'\s?hp\s?15\s?[a-z]\d{3}[a-z]{1,2}',  r'\shp\s?12\s?.{5}',
         r'\s?elitebook\srevolve\s?\d{3}\s?', '\s.\d{3}[pgmwm][pgmwm]?']
for t in hp:
    found = False
    for r in regex: 
        cr = re.compile(r)
        if re.search(cr, t):
#             print(re.search(cr, t).group())
            c+=1
            found = True
            break
    if not found:
        print(t)  
        pass
print()
print(c)
# Out:
# hp 15 series laptop brand new 500 gb ebay
# new hp 15 6 laptop 500gb hdd 4gb memory dual core windows 8 hdmi webcam wifi ebay
#
# 197

# %%
# Clean X4
x4_org = pd.read_csv('../data/sigmod/X4.csv')

# %%
def clean_products_dataset(x_org):
    replace_words = {
        'professional': 'pro',
        'data traveler': 'datatraveler',
        ' hx ': 'hyperx',
        'generation': 'g',
        ' micro sd': ' microsd',
        ' extrem ': 'extreme',
        ' classe ': 'class'
    }

    remove_words = ['tesco', 'direct', 'accessoires' ,'montres', 'bracelets', 'connects' ]
    
    all_brands = ['lexar', 'sony', 'sandisk', 'pny', 'kingston', 'samsung',
       'intenso', 'toshiba', 'transcend']
    
    brand_lines = {'lexar': {'stick': ['xqd', 'xqd pro', 'platinum'],
                             'flash': ['jumpdrive'],
                             'mobile': [],
                             'tv': []},
                   'sony': {'stick': [], 'flash': [], 'mobile': [], 'tv': []},
                   'sandisk': {'stick': ['extreme pro', 'ultra plus', 'ultra'], 
                               'flash': ['cruzer glide', 'cruzer edge', 'cruzer fit', 'cruzer'],
                               'mobile': [], 'tv': []},
                   'pny': {'stick': [], 'flash': [], 'mobile': [], 'tv': []},
                   'kingston': 
                   {
                       'stick': ['ultimate', 'hyperx'],
                       'flash': ['datatraveler', 'hyperx savage', 'hyperx'],
                       'mobile': [], 'tv': []
                   },
                   'samsung': {'stick': [], 'flash': [], 'mobile': [], 'tv': []},
                   'intenso': {'stick': [], 'flash': [], 'mobile': [], 'tv': []},
                   'toshiba': {'stick': ['exceria pro', 'exceria'],
                               'flash': [], 'mobile': [], 'tv': []},
                   'transcend': {'stick': [], 'flash': [], 'mobile': [], 'tv': []}}
    
    model_regex = {'lexar': {
                         'stick': [r'\s\d{3,4}x'],
                         'flash': [r'\sv\d\d.?', r'\sp\d\d.?', r'\sc\d\d.?', r'\ss\d\d.?'],
                         'mobile': [],
                         'tv': []
                    },
               'sony': {'stick': [], 'flash': [], 'mobile': [], 'tv': []},
               'sandisk': {'stick': [r'\s\d{4}x', r'x\d{2}', ],
                           'flash': [], 'mobile': [], 'tv': []},
               'pny': {'stick': [], 'flash': [], 'mobile': [], 'tv': []},
                   
               'kingston': {'stick': [],
                            'flash': [r'dt\d\d\d(g\d)?', r'\sg\d', r'101', r'g\d'],
                            'mobile': [], 'tv': []},
                   
               'samsung': {'stick': [], 'flash': [], 'mobile': [], 'tv': []},
               'intenso': {'stick': [], 'flash': [], 'mobile': [], 'tv': []},
               'toshiba': {'stick': [r'[umn]\d{2,4}.?'], 'flash': [r'[umn]\d{2,4}.?'], 'mobile': [], 'tv': []},
               'transcend': {'stick': [], 'flash': [], 'mobile': [], 'tv': []}}
    
    class_regex = [r'class\s?\d{1,2}\s', r'\sc\d{1,2}\s']
    
    spacy.cli.download("en_core_web_sm")

    x4_dev = convert_numbers_to_strings(x_org, ['price']).copy(deep=True)
    x4_dev.set_index('instance_id', inplace=True)

    def get_type(record):
        name = record['name'].lower()
        
        for b, d in brand_lines.items():
            for w in d['stick']:
                if w in name:
                    return 'stick'
            
            for w in d['flash']:
                if w in name:
                    return 'flash'

        if pd.isna(record['size']):
            if 'tv' in name:
                return 'tv'
            return 'mobile'

        flash_keywords = ['usb', 'drive', 'flashdisk', 'cruzer']
        memory_stick_keywords = ['card', 'stick', 'sd', 'microsd', 'hc', 'class', 'speicherkarte']  # Add variants here

        is_flash = False
        is_memory = False

        for w in flash_keywords:
            if w in name:
                is_flash = True
                break

        for w in memory_stick_keywords:
            if w in name:
                is_memory = True
                break

        if is_flash:
            return 'flash'

        if is_memory:
            return 'stick'

        return 'stick'

    with open('../data/sigmod/translations_lookup_all.json') as fin:
        variants = json.load(fin)

    with open('../data/sigmod/langs_dict.json') as fin:
        json.load(fin)

    # Alpha numeric
    irrelevant_regex = re.compile(r'[^a-z0-9,.\-\s]')
    multispace_regex = re.compile(r'\s\s+')  # Why it doesn't work
    x4_dev.replace({r'[^\x00-\x7F]+': ''}, regex=True, inplace=True)

    for column in x4_dev.columns:
        if column == 'instance_id':
            continue
        x4_dev[column] = x4_dev[column].str.lower().str.replace(irrelevant_regex, ' ').str.replace(multispace_regex,
                                                                                                   ' ')

    x4_dev['product_type'] = x4_dev.apply(get_type, axis=1)
    x4_dev.drop('price', inplace=True, axis=1)
    x4_dev['size'] = x4_dev['size'].str.lower().str.replace(' ', '')
    x4_dev['size'] = x4_dev['size'].where(x4_dev['size'].notnull(), 0)
    
    
    def get_line(record):
        name = record['name'].lower()
        brand = record['brand']
        product_type = record['product_type'] 

        for w in brand_lines[brand][product_type]:
            if w in name:
                return w

        return None

    def get_model_number(record):
        name = record['name'].lower()
        brand = record['brand']
        product_type = record['product_type'] 
        
        for t in model_regex[brand][product_type]:
            cr = re.compile(t)
            if re.search(cr, name):
                return re.search(cr, name).group()
        
        return None
    
    x4_dev['line'] = x4_dev.apply(get_line, axis=1)
    x4_dev['model'] = x4_dev.apply(get_model_number, axis=1)

    # Remove unwanted words from the name
    for i in range(len(x4_dev)):
        record = x4_dev.iloc[i]

        name = record['name']

        # remove unnecessary characters
        basic_punct = '-/\*_,:;/()®™'
        punct_to_space = str.maketrans(basic_punct, ' ' * len(basic_punct))  # map punctuation to space
        name = name.translate(punct_to_space)

        # remove brand
        name = name.replace(record['brand'], '')

        # remove size

        if record.product_type in ['flash', 'stick']:
            name = re.sub('\d\d\d\s?gb', '', name, 6)
            name = re.sub('\d\d\s?gb', '', name, 6)
            name = re.sub('\d\s?gb', '', name, 6)

        tokens = name.split(' ')
        for wd, wdtl in variants.items():
            while wd in tokens:
                tokens.remove(wd)
            for wdt in wdtl:
                while wdt in tokens:
                    tokens.remove(wdt)

        unneeded_words = ['mmoire', 'speicherkarte', 'flashgeheugenkaart', 'flash', 'stick', 'speed', 'high']
        for w in unneeded_words:
            while w in tokens:
                tokens.remove(w)
        x4_dev.iloc[i]['name'] = ' '.join(tokens)

    for column in x4_dev.columns:
        if column == 'instance_id':
            continue
        x4_dev[column] = x4_dev[column].str.lower().str.replace(irrelevant_regex, ' ').str.replace(multispace_regex,
                                                                                                   ' ')

    return x4_dev

# %%
x4_dev = clean_products_dataset(x4_org)
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# /Users/abdeas0a/opt/anaconda3/envs/sandbox/lib/python3.7/site-packages/ipykernel_launcher.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
x4_dev.head()
# Out:
#                                                                 name    brand  \
# instance_id
# altosight.com//0   lexar 32gb 1400x 210mb s professional xqd memr...    lexar
# altosight.com//25  sony microsdxc uhs-1 u3 128gb memriakrtya adap...     sony
# altosight.com//66  sandisk dual drive, type-c, usb 3.0, 16gb, 130...  sandisk
# altosight.com//68  sandisk dual drive, type-c, usb 3.0, 64gb, 150...  sandisk
# altosight.com//94  lexar xqd 32gb x1400 professional xqd kupon pr...    lexar
#
#                     size product_type  line  number
# instance_id
# altosight.com//0    32gb        stick   xqd   1400x
# altosight.com//25  128gb        stick  None    None
# altosight.com//66   16gb        flash  None    None
# altosight.com//68   64gb        flash  None    None
# altosight.com//94   32gb        stick   xqd    None

# %%
all_brands = x4_dev.brand.unique()
all_brands
# Out:
# array(['lexar', 'sony', 'sandisk', 'pny', 'kingston', 'samsung',
#        'intenso', 'toshiba', 'transcend'], dtype=object)

# %%
x4_dev.product_type.unique()
# Out:
# array(['stick', 'flash', 'mobile', 'tv'], dtype=object)

# %%
replace_words = {
    'professional': 'pro'
    'data traveler': 'datatraveler'
    ' hx ': 'hyperx',
    'generation': 'g',
    ' micro sd': ' microsd',
    ' extrem ': 'extreme',
    ' classe ': 'class'
}

remove_words = ['tesco', 'direct', 'accessoires' ,'montres', 'bracelets', 'connects' ]

# %%
def assign_line(record):
    brand = record['brand']
    product_type = record['product_type']
    
    all_brands = ['lexar', 'sony', 'sandisk', 'pny', 'kingston', 'samsung',
       'intenso', 'toshiba', 'transcend']
    
    brand_lines = {'lexar': {'stick': ['xqd', 'xqd pro', 'platinum'],
                             'flash': ['jumpdrive'],
                             'mobile': [],
                             'tv': []},
                   'sony': {'stick': [], 'flash': [], 'mobile': [], 'tv': []},
                   'sandisk': {'stick': ['extreme pro', 'ultra plus', 'ultra'], 
                               'flash': ['cruzer glide', 'cruzer edge', 'cruzer fit', 'cruzer'],
                               'mobile': [], 'tv': []},
                   'pny': {'stick': [], 'flash': [], 'mobile': [], 'tv': []},
                   'kingston': 
                   {
                       'stick': ['ultimate', 'hyperx'],
                       'flash': ['datatraveler', 'hyperx savage', 'hyperx'],
                       'mobile': [], 'tv': []
                   },
                   'samsung': {'stick': [], 'flash': [], 'mobile': [], 'tv': []},
                   'intenso': {'stick': [], 'flash': [], 'mobile': [], 'tv': []},
                   'toshiba': {'stick': ['exceria pro', 'exceria'],
                               'flash': [], 'mobile': [], 'tv': []},
                   'transcend': {'stick': [], 'flash': [], 'mobile': [], 'tv': []}}
    
    model_regex = {'lexar': {
                         'stick': [r'\s\d{3,4}x'],
                         'flash': [r'\sv\d\d.?', r'\sp\d\d.?', r'\sc\d\d.?', r'\ss\d\d.?'],
                         'mobile': [],
                         'tv': []
                    },
               'sony': {'stick': [], 'flash': [], 'mobile': [], 'tv': []},
               'sandisk': {'stick': [r'\s\d{4}x', r'x\d{2}', ],
                           'flash': [], 'mobile': [], 'tv': []},
               'pny': {'stick': [], 'flash': [], 'mobile': [], 'tv': []},
                   
               'kingston': {'stick': [],
                            'flash': [r'dt\d\d\d(g\d)?', r'\sg\d', r'101', r'g\d'],
                            'mobile': [], 'tv': []},
                   
               'samsung': {'stick': [], 'flash': [], 'mobile': [], 'tv': []},
               'intenso': {'stick': [], 'flash': [], 'mobile': [], 'tv': []},
               'toshiba': {'stick': [r'[umn]\d{2,4}.?'], 'flash': [r'[umn]\d{2,4}.?'], 'mobile': [], 'tv': []},
               'transcend': {'stick': [], 'flash': [], 'mobile': [], 'tv': []}}
    
    class_regex = [r'class\s?\d{1,2}\s', r['\sc\d{1,2}\s']]
    
    if brand not in all_brands:
        return None
    
    if product_type not in list(brand_lines[brand].keys()):
        return None
    
    # Check in the name for the possible brand lines

# %%
brand_lines = {}
for b in all_brands: 
    brand_lines[b] = {
        'stick': [],
        'flash': [],
        'mobile': [],
        'tv': []
    }

# %%
brand_lines
# Out:
# {'lexar': {'stick': [], 'flash': [], 'mobile': [], 'tv': []},
#  'sony': {'stick': [], 'flash': [], 'mobile': [], 'tv': []},
#  'sandisk': {'stick': [], 'flash': [], 'mobile': [], 'tv': []},
#  'pny': {'stick': [], 'flash': [], 'mobile': [], 'tv': []},
#  'kingston': {'stick': [], 'flash': [], 'mobile': [], 'tv': []},
#  'samsung': {'stick': [], 'flash': [], 'mobile': [], 'tv': []},
#  'intenso': {'stick': [], 'flash': [], 'mobile': [], 'tv': []},
#  'toshiba': {'stick': [], 'flash': [], 'mobile': [], 'tv': []},
#  'transcend': {'stick': [], 'flash': [], 'mobile': [], 'tv': []}}

# %%
x4_dev.groupby('brand').count()
# Out:
#            name  size  product_type
# brand
# intenso      61    61            61
# kingston    115   115           115
# lexar       163   163           163
# pny          29    29            29
# samsung      42    12            42
# sandisk     171   171           171
# sony         99    99            99
# toshiba     146   146           146
# transcend     9     9             9
