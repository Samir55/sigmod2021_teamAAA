# %%
import pandas as pd
import numpy as np

# %%
# read the data
left_x2 = pd.read_csv('../data/sigmod/X2.csv')
right_x2 = pd.read_csv('../data/sigmod/X2.csv')
y2 = pd.read_csv('../data/sigmod/Y2.csv')

# %%
left_new_columns = []
right_new_columns = []
for col in list(left_x2.columns):
    right_new_columns.append('right_' + col)
    left_new_columns.append('left_' + col)
    
left_x2.columns = left_new_columns
right_x2.columns = right_new_columns

left_x2.head()
# Out:
#            left_instance_id left_brand  \
# 0  www.softwarecity.ca//737     Lenovo
# 1  www.isupplyhub.com//1256       Acer
# 2   www.isupplyhub.com//326       Acer
# 3   www.isupplyhub.com//821         HP
# 4   www.isupplyhub.com//157       Asus
#
#                                left_cpu_brand left_cpu_model  \
# 0                             Intel. i5-3320M       i5-3320M
# 1  1.6 GHz Intel Core i5-4200U. Intel Core I5            NaN
# 2        1.6 GHz Intel Core i5. Intel Core I5            NaN
# 3                                         NaN            NaN
# 4                1.7 GHz Core i5-3317U. Intel            NaN
#
#                    left_cpu_type           left_cpu_frequency  \
# 0  Dual-core ( 2 Core ). Core i5                     2.60 GHz
# 1    1.6 GHz Intel Core i5-4200U  1.6 GHz Intel Core i5-4200U
# 2          1.6 GHz Intel Core i5        1.6 GHz Intel Core i5
# 3                            NaN                          NaN
# ...

# %%
right_x2.head()
# Out:
#           right_instance_id right_brand  \
# 0  www.softwarecity.ca//737      Lenovo
# 1  www.isupplyhub.com//1256        Acer
# 2   www.isupplyhub.com//326        Acer
# 3   www.isupplyhub.com//821          HP
# 4   www.isupplyhub.com//157        Asus
#
#                               right_cpu_brand right_cpu_model  \
# 0                             Intel. i5-3320M        i5-3320M
# 1  1.6 GHz Intel Core i5-4200U. Intel Core I5             NaN
# 2        1.6 GHz Intel Core i5. Intel Core I5             NaN
# 3                                         NaN             NaN
# 4                1.7 GHz Core i5-3317U. Intel             NaN
#
#                   right_cpu_type          right_cpu_frequency  \
# 0  Dual-core ( 2 Core ). Core i5                     2.60 GHz
# 1    1.6 GHz Intel Core i5-4200U  1.6 GHz Intel Core i5-4200U
# 2          1.6 GHz Intel Core i5        1.6 GHz Intel Core i5
# 3                            NaN                          NaN
# ...

# %%
len(y2)
# Out:
# 58653

# %%
y2.head()
# Out:
#             left_instance_id     right_instance_id  label
# 0  www.flexshopper.com//1098  www.amazon.com//1389      1
# 1        www.amazon.com//291  www.amazon.com//1081      1
# 2               buy.net//634  www.amazon.com//1014      1
# 3       www.amazon.com//2395          buy.net//393      1
# 4  www.flexshopper.com//2173          buy.net//634      1

# %%
left_x2 = pd.merge(y2, left_x2, on='left_instance_id',how='left')

# %%
x2 = pd.merge(left_x2, right_x2, on='right_instance_id',how='left')

# %%
left_x2.head()
# Out:
#             left_instance_id     right_instance_id  label left_brand  \
# 0  www.flexshopper.com//1098  www.amazon.com//1389      1        NaN
# 1        www.amazon.com//291  www.amazon.com//1081      1        NaN
# 2               buy.net//634  www.amazon.com//1014      1        NaN
# 3       www.amazon.com//2395          buy.net//393      1       Acer
# 4  www.flexshopper.com//2173          buy.net//634      1        NaN
#
#                                       left_cpu_brand  \
# 0  Intel Core i3 ( 4th Gen ) 4010U / 1.7 GHz / 3 ...
# 1                                      Intel Core i3
# 2                                      Intel Core i3
# 3                                      Intel Core i3
# 4  Intel Core i3 ( 4th Gen ) 4010U / 1.7 GHz / 3 ...
#
#                                       left_cpu_model  \
# 0  Intel Core i3 ( 4th Gen ) 4010U / 1.7 GHz / 3 ...
# 1                                      Intel Core i3
# 2                                                NaN
# ...

# %%
right_x2.head()
# Out:
#           right_instance_id right_brand  \
# 0  www.softwarecity.ca//737      Lenovo
# 1  www.isupplyhub.com//1256        Acer
# 2   www.isupplyhub.com//326        Acer
# 3   www.isupplyhub.com//821          HP
# 4   www.isupplyhub.com//157        Asus
#
#                               right_cpu_brand right_cpu_model  \
# 0                             Intel. i5-3320M        i5-3320M
# 1  1.6 GHz Intel Core i5-4200U. Intel Core I5             NaN
# 2        1.6 GHz Intel Core i5. Intel Core I5             NaN
# 3                                         NaN             NaN
# 4                1.7 GHz Core i5-3317U. Intel             NaN
#
#                   right_cpu_type          right_cpu_frequency  \
# 0  Dual-core ( 2 Core ). Core i5                     2.60 GHz
# 1    1.6 GHz Intel Core i5-4200U  1.6 GHz Intel Core i5-4200U
# 2          1.6 GHz Intel Core i5        1.6 GHz Intel Core i5
# 3                            NaN                          NaN
# ...

# %%
len(right_x2), len(left_x2), len(x2)
# Out:
# (343, 58653, 58653)

# %%
x2.head()
# Out:
#             left_instance_id     right_instance_id  label left_brand  \
# 0  www.flexshopper.com//1098  www.amazon.com//1389      1        NaN
# 1        www.amazon.com//291  www.amazon.com//1081      1        NaN
# 2               buy.net//634  www.amazon.com//1014      1        NaN
# 3       www.amazon.com//2395          buy.net//393      1       Acer
# 4  www.flexshopper.com//2173          buy.net//634      1        NaN
#
#                                       left_cpu_brand  \
# 0  Intel Core i3 ( 4th Gen ) 4010U / 1.7 GHz / 3 ...
# 1                                      Intel Core i3
# 2                                      Intel Core i3
# 3                                      Intel Core i3
# 4  Intel Core i3 ( 4th Gen ) 4010U / 1.7 GHz / 3 ...
#
#                                       left_cpu_model  \
# 0  Intel Core i3 ( 4th Gen ) 4010U / 1.7 GHz / 3 ...
# 1                                      Intel Core i3
# 2                                                NaN
# ...

# %%
len(x2)
# Out:
# 58653

# %%
# Save the output merged dataset
x2.to_csv('../data/sigmod/x2_train.csv', index=False)

# %%
len(x2)
# Out:
# 58653

# %%
x2['id'] = pd.Series(np.arange(len(x2)))

# %%
len(set(x2.id))
# Out:
# 58653
